# %% [markdown]
# # 딥러닝3 : 다중분류

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Input
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/iris.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# ### (1) y 값을 0,1,2로 변환하기
# (sparse_categorical_crossentropy 사용을 위해)

# %%
data['Species'] = data['Species'].map({'setosa':0, 'versicolor':1, 'virginica':2})
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# ### (2) 데이터 준비

# %%
target = 'Species'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (3) 데이터 분할 : train : val

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .3, random_state = 20)

# %% [markdown]
# ### (4) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.모델링1

# %% [markdown]
# ### (1) 모델 설계

# %%
nfeatures = x_train.shape[1] #num of columns
nfeatures
# Out:
# 4

# %%
# 메모리 정리
clear_session()

# Sequential
model = Sequential( [Input(shape = (nfeatures,)),
                     Dense( 3, activation = 'softmax')] )

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 3)                   │              15 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15 (60.00 B)
#  Trainable params: 15 (60.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### (2) compile + 학습

# %%
model.compile(optimizer=Adam(learning_rate=0.1), loss= 'sparse_categorical_crossentropy')

history = model.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 412ms/step - loss: 1.1216 - val_loss: 0.9183
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.8947 - val_loss: 0.7829
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.7772 - val_loss: 0.6522
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.6954 - val_loss: 0.5545
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.6114 - val_loss: 0.4832
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5754 - val_loss: 0.4366
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5100 - val_loss: 0.4023
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4813 - val_loss: 0.3774
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.4492 - val_loss: 0.3555
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4243 - val_loss: 0.3379
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3823 - val_loss: 0.3240
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3620 - val_loss: 0.3131
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3667 - val_loss: 0.3094
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3645 - val_loss: 0.2909
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3439 - val_loss: 0.2853
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3449 - val_loss: 0.2756
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3282 - val_loss: 0.2657
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3225 - val_loss: 0.2647
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3344 - val_loss: 0.2532
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3087 - val_loss: 0.2474
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2869 - val_loss: 0.2438
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2992 - val_loss: 0.2369
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2615 - val_loss: 0.2321
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2662 - val_loss: 0.2289
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2609 - val_loss: 0.2236
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2596 - val_loss: 0.2195
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2521 - val_loss: 0.2161
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2510 - val_loss: 0.2120
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2380 - val_loss: 0.2086
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2620 - val_loss: 0.2051
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2530 - val_loss: 0.2019
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2343 - val_loss: 0.1987
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2253 - val_loss: 0.1961
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2467 - val_loss: 0.1933
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2432 - val_loss: 0.1916
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2181 - val_loss: 0.1873
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2026 - val_loss: 0.1872
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2247 - val_loss: 0.1838
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2041 - val_loss: 0.1796
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.2276 - val_loss: 0.1774
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2131 - val_loss: 0.1749
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2144 - val_loss: 0.1763
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2098 - val_loss: 0.1737
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2003 - val_loss: 0.1693
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1935 - val_loss: 0.1675
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1917 - val_loss: 0.1657
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2021 - val_loss: 0.1625
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1988 - val_loss: 0.1614
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1867 - val_loss: 0.1629
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.1851 - val_loss: 0.1593

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증
# * 예측 결과는 softmax로 변환된 값 입니다.

# %%
y_val[:5]
# Out:
# 47     0
# 73     1
# 74     1
# 129    2
# 67     1
# Name: Species, dtype: int64

# %%
pred = model.predict(x_val)
pred[:5]
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# array([[9.7858274e-01, 2.1364724e-02, 5.2547766e-05],
#        [1.1648616e-02, 7.7846783e-01, 2.0988347e-01],
#        [1.3329384e-02, 7.2682369e-01, 2.5984684e-01],
#        [3.4581788e-04, 2.9157948e-01, 7.0807463e-01],
#        [3.4966171e-02, 8.8064146e-01, 8.4392391e-02]], dtype=float32)

# %% [markdown]
# * 행 별로 제일 큰 값을 찾아서 그에 맞게 숫자(0,1,2)로 변환 합시다.

# %%
# 5개 행만 살펴보면
np.argmax(pred[:5], axis = 1)
# Out:
# array([0, 1, 1, 2, 1])

# %%
# 전체에 적용해서 변환합시다.
pred_1 = pred.argmax(axis=1)
pred_1
# Out:
# array([0, 1, 1, 2, 1, 1, 2, 0, 2, 0, 2, 1, 1, 0, 0, 2, 0, 1, 2, 1, 1, 2,
#        2, 0, 1, 1, 1, 0, 2, 1, 1, 1, 0, 0, 0, 1, 2, 0, 1, 2, 1, 1, 0, 1,
#        2])

# %% [markdown]
# * 실제값 y_val은 0,1,2 로 된 1차원 값입니다.

# %%
y_val
# Out:
# 47     0
# 73     1
# 74     1
# 129    2
# 67     1
# 89     1
# 143    2
# 21     0
# 108    2
# 12     0
# 147    2
# 76     1
# 119    2
# 35     0
# 28     0
# 122    2
# 13     0
# 58     1
# 114    2
# 57     1
# 50     1
# 149    2
# 111    2
# 20     0
# 72     1
# 81     1
# 98     1
# 34     0
# 104    2
# 133    2
# 95     1
# 88     1
# 0      0
# 46     0
# 11     0
# 106    2
# 85     1
# 1      0
# 51     1
# 130    2
# 55     1
# 134    2
# 37     0
# 65     1
# 56     1
# Name: Species, dtype: int64

# %%
print(confusion_matrix(y_val, pred_1))
print(classification_report(y_val, pred_1))
# Out:
# [[13  0  0]
#  [ 0 16  2]
#  [ 0  4 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.80      0.89      0.84        18
#            2       0.83      0.71      0.77        14
#
#     accuracy                           0.87        45
#    macro avg       0.88      0.87      0.87        45
# weighted avg       0.87      0.87      0.87        45

# %% [markdown]
# ----

# %% [markdown]
# ## 4.모델링2 : hidden layer

# %% [markdown]
# ### (1) 모델1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # | 옵션 |
# | ---- | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 40 | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 3) | 27 | node, activation = 'softmax'  |

# %%
n=x_train.shape[1]
n
# Out:
# 4

# %%
clear_session()

model1=Sequential([Input(shape=(n,)),
                  Dense(8,activation='relu'),
                  Dense(3,activation='softmax')])

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              27 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 67 (268.00 B)
#  Trainable params: 67 (268.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile + 학습

# %%
model1.compile(optimizer=Adam(learning_rate=0.1), loss= 'sparse_categorical_crossentropy')

history = model1.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0681 - val_loss: 0.3464
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1719 - val_loss: 0.1423
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1086 - val_loss: 0.1190
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0458 - val_loss: 0.0526
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0718 - val_loss: 0.0475
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0353 - val_loss: 0.1154
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0713 - val_loss: 0.0792
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0340 - val_loss: 0.0455
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0442 - val_loss: 0.0450
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0332 - val_loss: 0.0650
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0308 - val_loss: 0.0668
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0310 - val_loss: 0.0502
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0279 - val_loss: 0.0444
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0360 - val_loss: 0.0481
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0222 - val_loss: 0.0656
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0362 - val_loss: 0.0587
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0325 - val_loss: 0.0503
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0280 - val_loss: 0.0502
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0295 - val_loss: 0.0539
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0277 - val_loss: 0.0466
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0476 - val_loss: 0.0396
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0289 - val_loss: 0.1087
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0611 - val_loss: 0.0516
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0238 - val_loss: 0.0427
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0272 - val_loss: 0.0539
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0296 - val_loss: 0.0553
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0324 - val_loss: 0.0422
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0317 - val_loss: 0.0589
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0333 - val_loss: 0.1075
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0288 - val_loss: 0.0389
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0413 - val_loss: 0.0388
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0228 - val_loss: 0.0852
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0311 - val_loss: 0.0620
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0181 - val_loss: 0.0380
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0256 - val_loss: 0.0683
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0310 - val_loss: 0.0538
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0452 - val_loss: 0.0374
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0459 - val_loss: 0.1015
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0118 - val_loss: 0.0387
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0486 - val_loss: 0.0477
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0462 - val_loss: 0.1726
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0689 - val_loss: 0.0405
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0500 - val_loss: 0.0518
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0340 - val_loss: 0.0983
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0469 - val_loss: 0.0606
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0308 - val_loss: 0.0466
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0249 - val_loss: 0.0938
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0315 - val_loss: 0.0545
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0313 - val_loss: 0.0443
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0582 - val_loss: 0.0942

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-34ab0feb4372> in <cell line: 1>()
# ----> 1 dl_history_plot(result)
#
# <ipython-input-2-3b6687c41727> in dl_history_plot(history)
#       2 def dl_history_plot(history):
#       3     plt.figure(figsize=(10,6))
# ----> 4     plt.plot(history['loss'], label='train_err', marker = '.')
#       5     plt.plot(history['val_loss'], label='val_err', marker = '.')
#       6
#
# TypeError: tuple indices must be integers or slices, not str

# %% [markdown]
# * 예측 및 검증
#     * 예측 결과는 softmax로 변환된 값 입니다.

# %% [markdown]
# ### (2) 모델2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # | 옵션 |
# | ---- | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 40 | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 8) | 72 | node, activation = 'relu'  |
# | dense_2 (Dense) | (None, 3) | 27 | node, activation = 'softmax'  |

# %%
n= x_train.shape[1]
n
model2=Sequential([Input(shape=(n,)),
                   Dense(8,activation='relu'),
                   Dense(8,activation='relu'),
                   Dense(3,activation='softmax') ])

model2.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                     │ (None, 8)                   │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 8)                   │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 3)                   │              27 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 139 (556.00 B)
#  Trainable params: 139 (556.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile + 학습

# %%
model2.compile(optimizer=Adam(learning_rate=0.01), loss= 'sparse_categorical_crossentropy')

history = model2.fit(x_train, y_train, epochs = 100, validation_split=0.2).history
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 329ms/step - loss: 1.0766 - val_loss: 1.0440
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.0295 - val_loss: 0.9953
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.9891 - val_loss: 0.9481
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.9458 - val_loss: 0.9039
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.8994 - val_loss: 0.8576
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.8819 - val_loss: 0.8092
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.8097 - val_loss: 0.7580
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7799 - val_loss: 0.7105
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.7307 - val_loss: 0.6631
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6868 - val_loss: 0.6170
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6451 - val_loss: 0.5741
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6029 - val_loss: 0.5341
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5718 - val_loss: 0.4974
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5366 - val_loss: 0.4640
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5007 - val_loss: 0.4331
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4809 - val_loss: 0.4050
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4326 - val_loss: 0.3801
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3924 - val_loss: 0.3582
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4030 - val_loss: 0.3407
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3935 - val_loss: 0.3254
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3758 - val_loss: 0.3061
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3598 - val_loss: 0.2908
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3214 - val_loss: 0.2768
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3241 - val_loss: 0.2628
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2895 - val_loss: 0.2501
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2938 - val_loss: 0.2372
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2629 - val_loss: 0.2264
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2714 - val_loss: 0.2155
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2373 - val_loss: 0.2049
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2342 - val_loss: 0.1954
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2454 - val_loss: 0.1857
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2217 - val_loss: 0.1772
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1975 - val_loss: 0.1688
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1979 - val_loss: 0.1629
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1784 - val_loss: 0.1529
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1782 - val_loss: 0.1457
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1786 - val_loss: 0.1382
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1591 - val_loss: 0.1321
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1535 - val_loss: 0.1247
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1583 - val_loss: 0.1226
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1363 - val_loss: 0.1152
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1280 - val_loss: 0.1096
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1432 - val_loss: 0.1087
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1337 - val_loss: 0.1050
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1181 - val_loss: 0.0978
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1068 - val_loss: 0.0960
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1170 - val_loss: 0.0915
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1002 - val_loss: 0.0899
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1059 - val_loss: 0.0868
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0916 - val_loss: 0.0842
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0849 - val_loss: 0.0818
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1036 - val_loss: 0.0783
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0916 - val_loss: 0.0763
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0997 - val_loss: 0.0791
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0855 - val_loss: 0.0742
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0859 - val_loss: 0.0704
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0814 - val_loss: 0.0695
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0694 - val_loss: 0.0671
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0821 - val_loss: 0.0795
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0769 - val_loss: 0.0678
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0754 - val_loss: 0.0653
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0758 - val_loss: 0.0618
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0832 - val_loss: 0.0645
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0819 - val_loss: 0.0650
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0680 - val_loss: 0.0582
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0644 - val_loss: 0.0577
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0837 - val_loss: 0.0625
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0605 - val_loss: 0.0622
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0775 - val_loss: 0.0550
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0653 - val_loss: 0.0564
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0777 - val_loss: 0.0540
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0758 - val_loss: 0.0585
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0611 - val_loss: 0.0527
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0724 - val_loss: 0.0506
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0694 - val_loss: 0.0497
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0637 - val_loss: 0.0491
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0703 - val_loss: 0.0554
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0656 - val_loss: 0.0494
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0583 - val_loss: 0.0482
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0673 - val_loss: 0.0508
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0501 - val_loss: 0.0455
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0631 - val_loss: 0.0609
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0712 - val_loss: 0.0557
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0621 - val_loss: 0.0446
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0689 - val_loss: 0.0481
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0761 - val_loss: 0.0435
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0548 - val_loss: 0.0453
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0564 - val_loss: 0.0481
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0658 - val_loss: 0.0425
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0564 - val_loss: 0.0436
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0464 - val_loss: 0.0417
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0439 - val_loss: 0.0412
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0578 - val_loss: 0.0439
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0533 - val_loss: 0.0393
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0452 - val_loss: 0.0396
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0497 - val_loss: 0.0400
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0538 - val_loss: 0.0404
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0515 - val_loss: 0.0417
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0482 - val_loss: 0.0372
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0446 - val_loss: 0.0381

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * 예측 및 검증
#     * 예측 결과는 softmax로 변환된 값 입니다.

# %% [markdown]
# ### (3) 모델3

# %% [markdown]
# * 여러분이 원하는 형태로 설계를 해 봅시다.

# %% [markdown]
# * compile + 학습

# %% [markdown]
# * 학습결과 그래프

# %% [markdown]
# * 예측 및 검증
#     * 예측 결과는 softmax로 변환된 값 입니다.

# %% [markdown]
# ## 5.참조 : y를 one-hot encoding 하여 모델링
#
# * y 가변수화 : to_categorical
# * 컴파일에서 loss = 'categorical_crossentropy'

# %%
from keras.utils import to_categorical

# %% [markdown]
# ### (1) y에 대한 가변수화

# %%
y

# %%
y_c = to_categorical(y.values, 3)

# %%
y_c[:5]

# %% [markdown]
# ### (2) 데이터 분할2 : train : val

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y_c, test_size = .3, random_state = 2022)

# %%
y_train.shape

# %%
x_train

# %%
y_train[:5]

# %% [markdown]
# ### (3) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (4) 모델 설계

# %%
nfeatures = x_train.shape[1] #num of columns
nfeatures

# %%
# 메모리 정리
clear_session()

# Sequential
model = Sequential([Input(shape = (nfeatures,)),
                    Dense(3, activation = 'softmax')])

# 모델요약
model.summary()

# %% [markdown]
# ### (5) compile + 학습
#
# * lr과 learning_rate은 같은 의미 입니다. 그러나 향후 버전에서는 lr이 제외될 예정이라고 합니다.
# * y를 one-hot encoding 했다면, loss fuction은 **categorical_crossentropy** 입니다.

# %%
model.compile(optimizer=Adam(learning_rate=0.1), loss='categorical_crossentropy')

history = model.fit(x_train, y_train, epochs = 100,
                    validation_split=0.2).history

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (6) 예측 및 평가
# * 예측 결과는 softmax로 변환된 값 입니다.

# %%
pred = model.predict(x_val)
pred[:5]

# %% [markdown]
# * 행 별로 제일 큰 값을 찾아서 그에 맞게 숫자(0,1,2)로 변환 합시다.

# %%
# 5개 행만 살펴보면
np.argmax(pred[:5], axis = 1)

# %%
y_val

# %%
# 전체에 적용해서 변환합시다.
pred_1 = pred.argmax(axis=1)
pred_1

# %% [markdown]
# * 실제값 y_val도 원래 대로 돌려 놓습니다.

# %%
y_val[:5]

# %%
y_val_1 = y_val.argmax(axis=1)
y_val_1

# %%
print(confusion_matrix(y_val_1, pred_1))
print(classification_report(y_val_1, pred_1))
