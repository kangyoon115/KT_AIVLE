# %% [markdown]
# # Classification : 2 Class

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Input
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 학습곡선 함수

# %%
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.3.csv"
data = pd.read_csv(path)
data.drop(['Age_scale1', 'AgeGroup', 'SibSp','Parch' ], axis = 1, inplace = True)
data.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  Family
# 0         0       3    male  22.0   7.2500        S       2
# 1         1       1  female  38.0  71.2833        C       2
# 2         1       3  female  26.0   7.9250        S       1
# 3         1       1  female  35.0  53.1000        S       2
# 4         0       3    male  35.0   8.0500        S       1

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# Sex, Age, Fare 만 이용하여 Survived 를 예측하는 모델을 만들어 봅시다.

# %% [markdown]
# ### (1) 데이터 준비

# %%
target = 'Survived'
features = ['Sex', 'Age', 'Fare']
x = data.loc[:, features]
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화

# %%
x = pd.get_dummies(x, columns = ['Sex'], drop_first = True)
x.head()
# Out:
#     Age     Fare  Sex_male
# 0  22.0   7.2500      True
# 1  38.0  71.2833     False
# 2  26.0   7.9250     False
# 3  35.0  53.1000     False
# 4  35.0   8.0500      True

# %% [markdown]
# ### (3) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# ### (4) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.딥러닝1: 3개 feature

# %% [markdown]
# ### (1) 모델설계

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 3

# %%
# 메모리 정리
clear_session()

# Sequential 모델 만들기
model = Sequential( [Input(shape = (nfeatures,)),
                     Dense( 1, activation= 'sigmoid')])

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4 (16.00 B)
#  Trainable params: 4 (16.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### (2) compile + 학습

# %%
model.compile(optimizer = Adam(learning_rate=0.01), loss = 'binary_crossentropy')

history = model.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5878 - val_loss: 0.5714
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5800 - val_loss: 0.5612
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5612 - val_loss: 0.5519
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5666 - val_loss: 0.5446
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5516 - val_loss: 0.5374
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5518 - val_loss: 0.5316
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5443 - val_loss: 0.5266
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5366 - val_loss: 0.5227
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5313 - val_loss: 0.5188
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5256 - val_loss: 0.5150
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5254 - val_loss: 0.5123
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5392 - val_loss: 0.5111
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5208 - val_loss: 0.5083
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5102 - val_loss: 0.5059
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5471 - val_loss: 0.5042
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5135 - val_loss: 0.5027
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5291 - val_loss: 0.5019
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5280 - val_loss: 0.5008
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5258 - val_loss: 0.5001
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5088 - val_loss: 0.4986
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4986 - val_loss: 0.4974
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5606 - val_loss: 0.4981
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5038 - val_loss: 0.4965
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5370 - val_loss: 0.4960
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5210 - val_loss: 0.4952
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5173 - val_loss: 0.4944
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4947 - val_loss: 0.4939
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5074 - val_loss: 0.4941
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4936 - val_loss: 0.4935
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5040 - val_loss: 0.4939
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5132 - val_loss: 0.4933
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5097 - val_loss: 0.4933
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5326 - val_loss: 0.4932
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5210 - val_loss: 0.4921
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5175 - val_loss: 0.4919
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4834 - val_loss: 0.4916
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4835 - val_loss: 0.4910
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4891 - val_loss: 0.4911
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4935 - val_loss: 0.4909
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5143 - val_loss: 0.4910
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4908 - val_loss: 0.4908
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4858 - val_loss: 0.4916
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4955 - val_loss: 0.4907
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5221 - val_loss: 0.4903
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4977 - val_loss: 0.4902
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4700 - val_loss: 0.4902
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4739 - val_loss: 0.4900
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4892 - val_loss: 0.4898
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5040 - val_loss: 0.4894
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4881 - val_loss: 0.4892

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증

# %%
pred = model.predict(x_val)
# pred[:5]
# activation이 sigmoid --> 0 ~ 1 사이의 확률값.
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
pred = np.where(pred >= .5, 1, 0)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84       170
#            1       0.73      0.68      0.71        98
#
#     accuracy                           0.79       268
#    macro avg       0.78      0.77      0.77       268
# weighted avg       0.79      0.79      0.79       268

# %% [markdown]
# ## 4.딥러닝2 : 전체 feature
# * 이제 전체 데이터를 가지고 모델링을 시도해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 준비

# %%
target = 'Survived'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# * 가변수화

# %%
cat_cols = ['Pclass','Sex', 'Embarked']
x = pd.get_dummies(x, columns = cat_cols, drop_first = True)

# %% [markdown]
# * 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 8

# %%
# 메모리 정리
clear_session()

model2=Sequential([ Input(shape=(nfeatures,)),
                   Dense(1, activation='sigmoid') ])

model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile + 학습

# %%
model2.compile(optimizer=Adam(learning_rate=0.1),loss='binary_crossentropy')

result=model2.fit(x_train,y_train,epochs=50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7450 - val_loss: 0.5524
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5494 - val_loss: 0.4896
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4994 - val_loss: 0.4654
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4801 - val_loss: 0.4647
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4618 - val_loss: 0.4506
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4435 - val_loss: 0.4513
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4829 - val_loss: 0.4444
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4693 - val_loss: 0.4402
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4617 - val_loss: 0.4440
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4712 - val_loss: 0.4418
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4322 - val_loss: 0.4491
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4349 - val_loss: 0.4410
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4459 - val_loss: 0.4392
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4187 - val_loss: 0.4456
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5003 - val_loss: 0.4465
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4325 - val_loss: 0.4360
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4195 - val_loss: 0.4415
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4338 - val_loss: 0.4423
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4526 - val_loss: 0.4424
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4262 - val_loss: 0.4435
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4332 - val_loss: 0.4423
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4518 - val_loss: 0.4398
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4508 - val_loss: 0.4523
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4229 - val_loss: 0.4440
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4292 - val_loss: 0.4547
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4409 - val_loss: 0.4487
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4136 - val_loss: 0.4484
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4205 - val_loss: 0.4467
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4261 - val_loss: 0.4444
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4294 - val_loss: 0.4482
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4305 - val_loss: 0.4483
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4039 - val_loss: 0.4515
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4391 - val_loss: 0.4433
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4344 - val_loss: 0.4472
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3921 - val_loss: 0.4559
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3991 - val_loss: 0.4493
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4352 - val_loss: 0.4525
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4214 - val_loss: 0.4452
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4265 - val_loss: 0.4520
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4169 - val_loss: 0.4514
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4394 - val_loss: 0.4493
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3833 - val_loss: 0.4518
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4528 - val_loss: 0.4484
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3913 - val_loss: 0.4518
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4417 - val_loss: 0.4547
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4121 - val_loss: 0.4524
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4543 - val_loss: 0.4450
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4255 - val_loss: 0.4578
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4363 - val_loss: 0.4515
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4627 - val_loss: 0.4556

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(result)

# %% [markdown]
# * 예측 및 검증

# %%
pred2 = model2.predict(x_val)
# pred[:5]
# activation이 sigmoid --> 0 ~ 1 사이의 확률값.
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
pred2 = np.where(pred2 >= .5, 1, 0)

print(classification_report(y_val, pred2))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       170
#            1       0.73      0.62      0.67        98
#
#     accuracy                           0.78       268
#    macro avg       0.77      0.75      0.75       268
# weighted avg       0.78      0.78      0.78       268

# %% [markdown]
# ----

# %% [markdown]
# ## 5.딥러닝3 : hidden layer
# * 이제 레이어를 추가해 보겠습니다.

# %% [markdown]
# ### (1) 모델 설계

# %%
n = x_train.shape[1]
n
# Out:
# 8

# %%
# 메모리 정리
clear_session()

# Sequential 모델
model3 = Sequential([Input(shape = (n,)),
                     Dense( 4, activation = 'relu'),
                     Dense( 1, activation = 'sigmoid')])

# 모델요약
model3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### (2) compile + 학습

# %%
model3.compile( optimizer=Adam(learning_rate= 0.01), loss ='binary_crossentropy')
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=.2 ).history
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.6595 - val_loss: 0.5931
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6254 - val_loss: 0.5675
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5851 - val_loss: 0.5418
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5546 - val_loss: 0.5140
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5325 - val_loss: 0.4911
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4868 - val_loss: 0.4735
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4970 - val_loss: 0.4597
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4770 - val_loss: 0.4495
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5209 - val_loss: 0.4433
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4357 - val_loss: 0.4349
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4613 - val_loss: 0.4293
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4396 - val_loss: 0.4256
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4194 - val_loss: 0.4226
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4448 - val_loss: 0.4173
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4492 - val_loss: 0.4179
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4083 - val_loss: 0.4145
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4302 - val_loss: 0.4136
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4240 - val_loss: 0.4112
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3956 - val_loss: 0.4095
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4194 - val_loss: 0.4095
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4204 - val_loss: 0.4088
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4068 - val_loss: 0.4108
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4088 - val_loss: 0.4082
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4414 - val_loss: 0.4059
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4088 - val_loss: 0.4067
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3880 - val_loss: 0.4089
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4081 - val_loss: 0.4047
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4011 - val_loss: 0.4032
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4253 - val_loss: 0.4057
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3892 - val_loss: 0.4031
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4380 - val_loss: 0.4027
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4099 - val_loss: 0.4038
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4501 - val_loss: 0.4030
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4358 - val_loss: 0.4035
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3688 - val_loss: 0.4040
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3737 - val_loss: 0.4015
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4149 - val_loss: 0.3998
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4007 - val_loss: 0.4040
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3860 - val_loss: 0.4017
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4199 - val_loss: 0.4040
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3997 - val_loss: 0.4035
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3945 - val_loss: 0.4028
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4150 - val_loss: 0.4031
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4166 - val_loss: 0.4011
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4400 - val_loss: 0.4039
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3839 - val_loss: 0.4007
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4136 - val_loss: 0.4027
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4174 - val_loss: 0.4013
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3898 - val_loss: 0.4033
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4527 - val_loss: 0.4014

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(hist)

# %% [markdown]
# * 예측 및 검증

# %%
pred3 = model3.predict(x_val)
pred3 = np.where(pred3 >= 0.5, 1, 0)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
print(classification_report(y_val, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.84       170
#            1       0.79      0.55      0.65        98
#
#     accuracy                           0.78       268
#    macro avg       0.79      0.73      0.75       268
# weighted avg       0.79      0.78      0.77       268

# %% [markdown]
# ### (3) 실습1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | 옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16)  | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 1) | node, activation = 'sigmoid' |

# %%
n=x_train.shape[1]
n
# Out:
# 8

# %%
clear_session()
model3=Sequential([Input(shape=(n,)),
                  Dense(16,activation='relu'),
                  Dense(1,activation='sigmoid')])

model3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 161 (644.00 B)
#  Trainable params: 161 (644.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model3.compile(optimizer=Adam(learning_rate=0.01),loss='binary_crossentropy')

result=model3.fit(x_train,y_train,epochs=50,validation_split=0.2).history
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6252 - val_loss: 0.5651
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5447 - val_loss: 0.5086
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4916 - val_loss: 0.4807
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4881 - val_loss: 0.4556
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4946 - val_loss: 0.4503
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4776 - val_loss: 0.4381
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4106 - val_loss: 0.4274
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4184 - val_loss: 0.4247
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4265 - val_loss: 0.4175
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4173 - val_loss: 0.4175
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4329 - val_loss: 0.4120
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3929 - val_loss: 0.4146
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4236 - val_loss: 0.4076
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4038 - val_loss: 0.4084
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4136 - val_loss: 0.4024
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4027 - val_loss: 0.4053
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3783 - val_loss: 0.4063
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3896 - val_loss: 0.3989
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3924 - val_loss: 0.4069
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3899 - val_loss: 0.4029
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3899 - val_loss: 0.4000
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3837 - val_loss: 0.4006
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3989 - val_loss: 0.3998
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3729 - val_loss: 0.3981
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3777 - val_loss: 0.4002
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3511 - val_loss: 0.4007
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3900 - val_loss: 0.3990
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4256 - val_loss: 0.3974
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3910 - val_loss: 0.3971
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4076 - val_loss: 0.4018
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4264 - val_loss: 0.4014
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4100 - val_loss: 0.3945
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4123 - val_loss: 0.3984
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3667 - val_loss: 0.3999
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3620 - val_loss: 0.4040
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3987 - val_loss: 0.3964
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4011 - val_loss: 0.3982
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3773 - val_loss: 0.4022
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3835 - val_loss: 0.3972
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3902 - val_loss: 0.3950
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3798 - val_loss: 0.3975
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3742 - val_loss: 0.4038
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3930 - val_loss: 0.4027
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4120 - val_loss: 0.3901
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3548 - val_loss: 0.3970
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4079 - val_loss: 0.3983
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4038 - val_loss: 0.4003
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3921 - val_loss: 0.3926
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3576 - val_loss: 0.4068
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4149 - val_loss: 0.4003

# %%
dl_history_plot(result)

# %%
pred3 = model3.predict(x_val)
# pred[:5]
# activation이 sigmoid --> 0 ~ 1 사이의 확률값.
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
pred3 = np.where(pred3 >= .5, 1, 0)

print(classification_report(y_val, pred3))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       170
#            1       0.74      0.60      0.66        98
#
#     accuracy                           0.78       268
#    macro avg       0.77      0.74      0.75       268
# weighted avg       0.77      0.78      0.77       268

# %% [markdown]
# ### (4) 실습2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape |  옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16) |  node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 8) |  node, activation = 'relu'  |
# | dense_2 (Dense) | (None, 1) |  node, activation = 'sigmoid'  |

# %% [markdown]
# ### (5) 실습3

# %% [markdown]
# * 이번에는 여러분이 원하는 대로 설계하고, 학습해 봅시다.
