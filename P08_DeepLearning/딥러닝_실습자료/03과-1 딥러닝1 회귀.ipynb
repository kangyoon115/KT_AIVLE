# %% [markdown]
# # 딥러닝1 : 회귀

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Input
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 학습곡선 그래프

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv'
data = pd.read_csv(path)
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# |	변수	|	설명	|
# |	----	|	----	|
# |	medv	|	타운별 집값(중위수)	|
# |	crim	|	범죄율	|
# |	zn	|	25,000 평방피트를 초과 거주지역 비율	|
# |	indus	|	비소매상업지역 면적 비율	|
# |	chas	|	찰스강변 위치(범주 : 강변1, 아니면 0)	|
# |	nox	|	일산화질소 농도	|
# |	rm	|	주택당 방 수	|
# |	age	|	1940년 이전에 건축된 주택의 비율	|
# |	dis	|	직업센터의 거리	|
# |	rad	|	방사형 고속도로까지의 거리	|
# |	tax	|	재산세율	|
# |	ptratio	|	학생/교사 비율	|
# |	lstat	|	인구 중 하위 계층 비율	|

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# lstat, ptratio, crim 만 이용하여 medv를 예측하는 모델을 만들어 봅시다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) 데이터 준비
# * x, y 나누기
#     * x : lstat, ptratio, crim
#     * y : medv

# %%
target = 'medv'
features = ['lstat', 'ptratio', 'crim']
x = data.loc[:, features]
y = data.loc[:, target]

# %% [markdown]
# ### (2) NaN 조치

# %% [markdown]
# ### (3) 가변수화

# %% [markdown]
# ### (4) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# ### (5) Scaling

# %%
# 스케일러 선언
scaler = MinMaxScaler()

# train 셋으로 fitting & 적용
x_train = scaler.fit_transform(x_train)

# validation 셋은 적용만!
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.딥러닝1 : 3개의 feature

# %% [markdown]
# ### (1) 모델설계

# %%
# 분석단위의 shape
nfeatures = x_train.shape[1] #num of columns
nfeatures
# Out:
# 3

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model=Sequential( [Input(shape=(nfeatures,)),
                   Dense(1)])

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4 (16.00 B)
#  Trainable params: 4 (16.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile
#     * optimizer = 'adam'    : 기본값으로 옵티마이저 사용(learning_rate = 0.001)
#     * optimizer = Adam(learning_rate = 0.1) : 옵션 값 조정 가능
#         * lr과 learning_rate은 같지만, learning_rate 사용을 권장

# %%
model.compile(optimizer=Adam(learning_rate=0.1),loss='mse')

# %% [markdown]
# ### (2) 학습

# %% [markdown]
# validation_split=0.2 : 학습시, 학습용 데이터에서 0.2 만큼 떼어 내서 검증셋으로 활용

# %%
history = model.fit(x_train, y_train, epochs = 30, validation_split=0.2).history
# Out:
# Epoch 1/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 600.9300 - val_loss: 555.5031
# Epoch 2/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 492.2279 - val_loss: 479.6603
# Epoch 3/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 429.8915 - val_loss: 416.1833
# Epoch 4/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 358.8734 - val_loss: 363.4253
# Epoch 5/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 317.4389 - val_loss: 321.1872
# Epoch 6/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 248.9234 - val_loss: 287.7314
# Epoch 7/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 233.0854 - val_loss: 261.8407
# Epoch 8/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 217.4050 - val_loss: 241.9210
# Epoch 9/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 199.5016 - val_loss: 225.7000
# Epoch 10/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 173.7534 - val_loss: 212.4458
# Epoch 11/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 185.5636 - val_loss: 201.8772
# Epoch 12/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 164.0193 - val_loss: 193.7758
# Epoch 13/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 160.3325 - val_loss: 186.8620
# Epoch 14/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 147.2779 - val_loss: 181.7437
# Epoch 15/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 145.4285 - val_loss: 177.3794
# Epoch 16/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 144.3251 - val_loss: 172.7604
# Epoch 17/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 130.7259 - val_loss: 168.9517
# Epoch 18/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 126.1990 - val_loss: 165.4403
# Epoch 19/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 113.6560 - val_loss: 161.9946
# Epoch 20/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 132.9114 - val_loss: 158.3167
# Epoch 21/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 126.4757 - val_loss: 155.0873
# Epoch 22/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 112.5445 - val_loss: 151.9907
# Epoch 23/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 134.4512 - val_loss: 148.7326
# Epoch 24/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 117.4212 - val_loss: 145.5852
# Epoch 25/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 99.1532 - val_loss: 142.1431
# Epoch 26/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 103.4747 - val_loss: 139.1141
# Epoch 27/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 125.9221 - val_loss: 135.8857
# Epoch 28/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 114.1199 - val_loss: 133.2595
# Epoch 29/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 112.8098 - val_loss: 130.8244
# Epoch 30/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 111.0460 - val_loss: 128.1966

# %% [markdown]
# * 학습결과 그래프

# %%
# 함수로 만들어서 사용합시다.
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증

# %%
pred=model.predict(x_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
print(f'RMSE : {mean_squared_error(y_val, pred, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_val, pred)}')
print(f'MAPE : {mean_absolute_percentage_error(y_val, pred)}')
# Out:
# RMSE : 8.72178221402276
# MAE  : 5.793481699625651
# MAPE : 0.29793538507627265
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ## 4.딥러닝2 : 전체 feature
# * 이제 전체 데이터를 가지고 모델링을 시도해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
nfeatures=x_train.shape[1]
nfeatures
# Out:
# 12

# %%
#메모리 정리
clear_session()

# Sequential 타입 모델 선언
model=Sequential( [Input(shape=(nfeatures, )),
                   Dense(1)])

# 모델 요약
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │              13 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile

# %%
model.compile(optimizer=Adam(learning_rate=0.1),loss='mse')

# %% [markdown]
# * 학습

# %%
result=model.fit(x_train,y_train, epochs = 35, validation_split=0.2).history
# Out:
# Epoch 1/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 50.7344 - val_loss: 47.6513
# Epoch 2/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.8240 - val_loss: 46.5427
# Epoch 3/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.9184 - val_loss: 45.1474
# Epoch 4/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.0878 - val_loss: 44.5482
# Epoch 5/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 54.1232 - val_loss: 43.6600
# Epoch 6/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.2724 - val_loss: 43.3738
# Epoch 7/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.4691 - val_loss: 42.5757
# Epoch 8/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 53.8424 - val_loss: 41.8126
# Epoch 9/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 44.2210 - val_loss: 41.9934
# Epoch 10/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 45.0294 - val_loss: 40.3530
# Epoch 11/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.4485 - val_loss: 40.0175
# Epoch 12/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.2575 - val_loss: 39.6793
# Epoch 13/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.3216 - val_loss: 39.4669
# Epoch 14/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.3528 - val_loss: 38.5874
# Epoch 15/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 46.3307 - val_loss: 38.1719
# Epoch 16/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 55.3862 - val_loss: 37.3013
# Epoch 17/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.4617 - val_loss: 36.7608
# Epoch 18/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.7204 - val_loss: 36.2993
# Epoch 19/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.7729 - val_loss: 35.5527
# Epoch 20/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.8124 - val_loss: 35.5685
# Epoch 21/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.8077 - val_loss: 35.2363
# Epoch 22/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.0826 - val_loss: 34.4215
# Epoch 23/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.7826 - val_loss: 34.4977
# Epoch 24/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.0817 - val_loss: 34.2326
# Epoch 25/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.5568 - val_loss: 33.8953
# Epoch 26/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 41.2811 - val_loss: 33.9656
# Epoch 27/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.4344 - val_loss: 33.7777
# Epoch 28/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.1956 - val_loss: 32.4091
# Epoch 29/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.2416 - val_loss: 31.8146
# Epoch 30/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.6406 - val_loss: 31.1309
# Epoch 31/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.2506 - val_loss: 31.5226
# Epoch 32/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.7455 - val_loss: 31.3991
# Epoch 33/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 42.8414 - val_loss: 30.2689
# Epoch 34/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.0340 - val_loss: 30.0983
# Epoch 35/35
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.6829 - val_loss: 30.1320

# %% [markdown]
# * 학습결과 그래프

# %%
# 함수로 만들어서 사용합시다.
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %%
dl_history_plot(result)

# %% [markdown]
# * 예측 및 평가

# %%
pred=model.predict(x_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
print(root_mean_squared_error(y_val,pred))
print(mean_absolute_error(y_val,pred))
print(mean_absolute_percentage_error(y_val,pred))
# Out:
# 6.337089622562819
# 4.735064485961317
# 0.2385631378717638

# %% [markdown]
# ## 5.실습!
# * 위 4번에 이어서, 여러분은 다음을 조절할 수 있습니다.
#     * epochs(반복횟수), learning_rate(학습율)
# * 4번 코드를 그대로 보면서 작성하고 위 두가지를 조절하며 성능을 높여봅시다!

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %% [markdown]
# * compile

# %% [markdown]
# * 학습

# %% [markdown]
# * 학습결과 그래프

# %% [markdown]
# * 예측 및 평가

# %% [markdown]
# ----

# %% [markdown]
# ## 5.딥러닝3 : hidden layer!
# * 이제 레이어를 추가해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 분할

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
nfeatures = x_train.shape[1] #num of columns
nfeatures
# Out:
# 12

# %%
# 메모리 정리
clear_session()

# Sequential 타입 모델 선언(입력은 리스트로!)
model3 = Sequential([Input(shape = (nfeatures,)),
                     Dense(2, activation = 'relu'),
                     Dense(1)   ])

# 모델요약
model3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 2)                   │              26 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29 (116.00 B)
#  Trainable params: 29 (116.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * compile

# %%
model3.compile(optimizer=Adam(learning_rate=0.1),loss='mse')

# %% [markdown]
# * 학습

# %%
result=model3.fit(x_train,y_train,epochs=50,validation_split= .2).history
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 597.9824 - val_loss: 603.6882
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 539.2381 - val_loss: 556.0297
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 515.2407 - val_loss: 511.2864
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 429.4156 - val_loss: 470.1040
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 383.2528 - val_loss: 431.6323
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 361.0443 - val_loss: 396.6871
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 342.2654 - val_loss: 364.8303
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 299.0712 - val_loss: 336.0859
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 302.1327 - val_loss: 309.5496
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 276.4815 - val_loss: 285.7523
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 242.3129 - val_loss: 264.1447
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 224.6537 - val_loss: 244.3969
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 219.4392 - val_loss: 227.2032
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 185.7275 - val_loss: 211.5856
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 167.3199 - val_loss: 197.6997
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 175.2925 - val_loss: 185.1824
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 141.5212 - val_loss: 173.7396
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 144.3277 - val_loss: 164.0759
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 123.4789 - val_loss: 155.7188
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 127.1090 - val_loss: 148.1977
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 134.9514 - val_loss: 140.9065
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 105.9242 - val_loss: 134.7776
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 114.5938 - val_loss: 129.6157
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 117.5981 - val_loss: 125.0699
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 103.4568 - val_loss: 121.1498
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 100.1891 - val_loss: 117.5646
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 91.0996 - val_loss: 114.3914
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 106.1290 - val_loss: 111.9664
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 95.4528 - val_loss: 109.8530
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 94.3267 - val_loss: 107.9729
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 99.4392 - val_loss: 106.5773
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 93.5908 - val_loss: 105.5409
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 94.3625 - val_loss: 104.6337
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 98.5972 - val_loss: 103.8955
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 78.1770 - val_loss: 103.1836
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 109.6594 - val_loss: 102.2402
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 92.9960 - val_loss: 101.5923
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 84.2496 - val_loss: 100.9720
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 93.4461 - val_loss: 100.5661
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 94.2531 - val_loss: 100.2678
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 95.0151 - val_loss: 100.1301
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 84.0121 - val_loss: 100.0526
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 84.7274 - val_loss: 99.7469
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 82.5991 - val_loss: 99.4465
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 74.9490 - val_loss: 99.4089
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 83.1810 - val_loss: 99.2924
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 101.7426 - val_loss: 99.0687
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 88.0763 - val_loss: 98.9600
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 82.2021 - val_loss: 98.7579
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 82.1895 - val_loss: 98.5344

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(result)

# %% [markdown]
# * 예측 및 평가

# %%
pred=model.predict(x_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
print(root_mean_squared_error(y_val,pred))
print(mean_absolute_error(y_val,pred))
print(mean_absolute_percentage_error(y_val,pred))
# Out:
# 4.772609791216298
# 3.7221270486420286
# 0.19240982854231004

# %% [markdown]
# ### (3) 실습1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 104 |
# | dense_1 (Dense) | (None, 1) | 9 |

# %%
clear_session()

model4=Sequential([Input(shape=(nfeatures,)),
                   Dense(8, activation='relu'),
                   Dense(1)])

model4.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │             104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 113 (452.00 B)
#  Trainable params: 113 (452.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * 컴파일 + 학습

# %%
model4.compile(optimizer=Adam(learning_rate=0.1),loss='mse')

# %% [markdown]
# * 학습곡선

# %%
result1=model4.fit(x_train,y_train,epochs=50,validation_split= .2).history
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 490.1497 - val_loss: 201.7509
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 189.1908 - val_loss: 131.4831
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 102.4497 - val_loss: 82.9888
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 83.6843 - val_loss: 58.3637
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.0538 - val_loss: 50.0053
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 57.6203 - val_loss: 44.2543
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.3839 - val_loss: 39.4728
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 44.7249 - val_loss: 34.6712
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 43.8235 - val_loss: 29.8421
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.9455 - val_loss: 23.8026
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.9858 - val_loss: 21.1639
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.3596 - val_loss: 18.6304
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.6848 - val_loss: 15.8259
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.0828 - val_loss: 17.5129
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.6957 - val_loss: 15.1472
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.0267 - val_loss: 14.6873
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.1241 - val_loss: 16.9152
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.9778 - val_loss: 13.5717
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.5827 - val_loss: 14.6067
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.0464 - val_loss: 13.0528
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.6807 - val_loss: 14.1686
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.2657 - val_loss: 12.0669
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.3055 - val_loss: 12.9412
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.6055 - val_loss: 14.1604
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.1898 - val_loss: 11.4767
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.4072 - val_loss: 11.5559
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.4980 - val_loss: 18.9209
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2108 - val_loss: 11.4223
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.0428 - val_loss: 18.5261
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.4656 - val_loss: 13.3698
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.2526 - val_loss: 12.0939
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.6424 - val_loss: 18.4852
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.8361 - val_loss: 21.0692
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.9701 - val_loss: 11.9554
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.1329 - val_loss: 10.8082
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.0197 - val_loss: 14.4258
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.1454 - val_loss: 17.1733
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.5010 - val_loss: 11.4530
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.0328 - val_loss: 18.6615
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.1795 - val_loss: 13.2684
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.6261 - val_loss: 11.8875
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.5239 - val_loss: 11.8901
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.1794 - val_loss: 15.3879
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4518 - val_loss: 14.0809
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.2055 - val_loss: 11.9125
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.2684 - val_loss: 23.6285
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.4499 - val_loss: 12.3671
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.3612 - val_loss: 13.6880
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.9279 - val_loss: 32.4869
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 49.0428 - val_loss: 29.9703

# %%
dl_history_plot(result1)

# %% [markdown]
# * 검증

# %%
pred=model4.predict(x_val)

print(root_mean_squared_error(y_val,pred))
print(mean_absolute_error(y_val,pred))
print(mean_absolute_percentage_error(y_val,pred))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 23.38373210444541
# 21.996128298966767
# 1.0214948991068278

# %% [markdown]
# ### (4) 실습2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # | 옵션 |
# | ---- | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 104 | node, input_shape, activation |
# | dense_1 (Dense) | (None, 4) | 36 | node, activation |
# | dense_2 (Dense) | (None, 1) | 5 | node |

# %%
clear_session()

model5=Sequential([Input(shape=(nfeatures,)),
                   Dense(8,activation='relu'),
                   Dense(4,activation='relu'),
                   Dense(1)])

model5.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │             104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 145 (580.00 B)
#  Trainable params: 145 (580.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * 컴파일 + 학습

# %%
model5.compile(optimizer= Adam(learning_rate=0.1),loss='mse')

# %%
result3=model5.fit(x_train,y_train,epochs=50,validation_split=0.2).history
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 482.0377 - val_loss: 192.5899
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 150.1238 - val_loss: 91.6040
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 87.4459 - val_loss: 63.6547
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.3187 - val_loss: 45.7761
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 60.0468 - val_loss: 56.3651
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.0562 - val_loss: 36.6206
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 50.2998 - val_loss: 37.1724
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.7297 - val_loss: 37.2051
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.4637 - val_loss: 19.6130
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.9643 - val_loss: 16.9518
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.0917 - val_loss: 14.7696
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.9967 - val_loss: 15.3777
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.8247 - val_loss: 13.8285
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.9106 - val_loss: 12.9345
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.3391 - val_loss: 13.8826
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.6298 - val_loss: 16.4494
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.5347 - val_loss: 16.9453
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.7444 - val_loss: 11.3633
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.5728 - val_loss: 12.0666
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.8808 - val_loss: 14.6351
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.8782 - val_loss: 10.6192
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.1646 - val_loss: 10.7061
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.3755 - val_loss: 13.6623
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.4689 - val_loss: 13.2875
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.8060 - val_loss: 12.6083
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.4932 - val_loss: 13.0597
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.3307 - val_loss: 12.2950
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.9841 - val_loss: 11.1685
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.1985 - val_loss: 15.9487
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.0434 - val_loss: 12.6594
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.2936 - val_loss: 20.5449
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.0922 - val_loss: 33.6551
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.7862 - val_loss: 19.6777
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.1972 - val_loss: 18.3518
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.7091 - val_loss: 13.2204
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.6275 - val_loss: 17.3552
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.0874 - val_loss: 14.4900
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.8797 - val_loss: 16.0250
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.6626 - val_loss: 14.6654
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.7967 - val_loss: 18.0090
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.2680 - val_loss: 12.9289
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.5403 - val_loss: 13.8356
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.8726 - val_loss: 13.0005
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.4456 - val_loss: 12.4424
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.9914 - val_loss: 15.2198
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.7018 - val_loss: 13.4779
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.5032 - val_loss: 13.4970
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.3419 - val_loss: 15.2416
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.6129 - val_loss: 13.3483
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.6816 - val_loss: 20.8229

# %% [markdown]
# * 학습곡선

# %%
dl_history_plot(result3)

# %% [markdown]
# * 검증

# %%
pred=model5.predict(x_val)

print(root_mean_squared_error(y_val,pred))
print(mean_absolute_error(y_val,pred))
print(mean_absolute_percentage_error(y_val,pred))
# Out:
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# WARNING:tensorflow:5 out of the last 21 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c270c1d95a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 4.282579951162052
# 3.0909553583930522
# 0.15210978839126002

# %% [markdown]
# * 회귀 모델 예측값 vs 실제값 그래프

# %%
def visualization_result(y_val,pred):
    plt.figure(figsize = (5,5))
    y = x = np.linspace(y_val.min(), y_val.max(), 10)

    y_range = y_val.max() - y_val.min()
    mi, ma = y_val.min() - y_range*0.1 , y_val.max()+ y_range*0.1

    sns.scatterplot(x= pred.reshape(-1), y = y_val.values) #x가 예측값, y가 실제값
    sns.lineplot(x = x, y = y, color = 'r')
    plt.xlim(mi, ma)
    plt.ylim(mi, ma)
    plt.grid()

    plt.show()

visualization_result(y_val,pred)
