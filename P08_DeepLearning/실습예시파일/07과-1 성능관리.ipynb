# %% [markdown]
# # **성능관리**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### **(1) 라이브러리 로딩**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Flatten, Input
from keras.backend import clear_session
from keras.optimizers import Adam
from keras.datasets import mnist

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### **(2) 데이터로딩**

# %% [markdown]
# * 데이터 로딩
#     * 과적합을 위한 예제 데이터입니다.
#     * target
#     * feature : 0 ~ 299

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/overfit_sample.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    target      0      1      2      3      4      5      6      7      8  ...  \
# 0       1 -1.067 -1.114 -0.616  0.376  1.090  0.467 -0.422  0.460 -0.443  ...
# 1       0 -0.831  0.271  1.716  1.096  1.731 -0.197  1.904 -0.265  0.557  ...
# 2       0  0.099  1.390 -0.732 -1.065  0.005 -0.081 -1.450  0.317 -0.624  ...
# 3       1 -0.989 -0.916 -1.343  0.145  0.543  0.636  1.127  0.189 -0.118  ...
# 4       0  0.811 -1.509  0.522 -0.360 -0.220 -0.959  0.334 -0.566 -0.656  ...
#
#      290    291    292    293    294    295    296    297    298    299
# 0  0.220 -0.339  0.254 -0.179  0.352  0.125  0.347  0.436  0.958 -0.824
# 1 -0.765 -0.735 -1.158  2.554  0.856 -1.506  0.462 -0.029 -1.932 -0.343
# 2 -1.311  0.799 -1.001  1.544  0.575 -0.309 -0.339 -0.148 -0.646  0.725
# 3 -1.370  1.093  0.596 -0.589 -0.649 -0.163 -0.958 -1.081  0.805  3.401
# 4 -0.178  0.718 -1.017  1.249 -0.596 -0.445  1.751  1.442 -0.393 -0.643
#
# [5 rows x 301 columns]

# %%
data.shape
# Out:
# (250, 301)

# %% [markdown]
# ## **2. Early Stopping**

# %% [markdown]
# ### **(1) 데이터 준비**

# %%
# 데이터분할 : x, y
target = 'target'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# 데이터분할 : train, validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %%
# 스케일링
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### **(2) 모델링**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(3) 미리 멈춤!(Early Stopping)**

# %% [markdown]
# #### 1) 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### 2) 모델링 with early stopping

# %%
# 모델 선언
clear_session()

model2 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )
model2.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# EarlyStopping 설정 ------------
min_de = 0.001
pat = 5

es = EarlyStopping(monitor = 'val_loss', min_delta = min_de, patience = pat)
# --------------------------------

# 학습
hist = model2.fit(x_train, y_train, epochs = 100, validation_split=0.2,
                  callbacks = [es]).history
dl_history_plot(hist)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - loss: 0.6382 - val_loss: 0.6045
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.5867 - val_loss: 0.5859
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5377 - val_loss: 0.5881
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5269 - val_loss: 0.5973
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5824 - val_loss: 0.5932
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5497 - val_loss: 0.6045
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5076 - val_loss: 0.6064

# %% [markdown]
# ## 3.Dropout

# %%
from keras.layers import Dropout

# %% [markdown]
# ### **(1) 적용 전**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) 적용 후**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model3 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dropout(0.4),
                      Dense(64, activation= 'relu'),
                      Dropout(0.4),
                      Dense(32, activation= 'relu'),
                      Dropout(0.4),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model3.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## 4.모델 저장하기

# %% [markdown]
# ### (1) 모델 저장하기
#
# * model.save(‘파일이름.keras’)
#     * 딥러닝 모델의 메소드로 .save가 제공됩니다.
#     * 파일이름.keras 파일이 저장됩니다.

# %%
model1.save('hanky.keras')

# %% [markdown]
# * 저장된 파일은 왼쪽 '파일'탭에서 확인 가능
# * 파일을 다운로드 받을 수 있다.

# %% [markdown]
# ### (2) 모델 로딩하기
#
# * load_model 함수는 별도로 불러와야 합니다.
# * 경로를 맞춰주고 h5 파일을 읽어오면 그대로 사용 가능합니다.

# %%
from keras.models import load_model
model2 = load_model('hanky.keras')

# %% [markdown]
# * 불러온 모델 사용하기

# %%
pred2 = model2.predict(x_val)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step

# %%
pred2

# %%
pred2_1 = np.where(pred2> .5, 1, 0)

# %%
print(accuracy_score(y_val,pred2_1))
print('-'*60)
print(confusion_matrix(y_val, pred2_1))
print('-'*60)
print(classification_report(y_val, pred2_1))
# Out:
# 0.68
# ------------------------------------------------------------
# [[30  5]
#  [11  4]]
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.86      0.79        35
#            1       0.44      0.27      0.33        15
#
#     accuracy                           0.68        50
#    macro avg       0.59      0.56      0.56        50
# weighted avg       0.65      0.68      0.65        50

# %% [markdown]
# ### (3) 중간 체크포인트에 모델 저장하기

# %% [markdown]
# * 폴더 정리 : 위에서 저장한 파일들 제거하기

# %%
import os

def delete_h5_files(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".keras"):
            file_path = os.path.join(directory, filename)
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

# 삭제할 디렉토리 지정
directory_to_delete_from = "/content/"

# 확장자가 .h5인 파일 삭제
delete_h5_files(directory_to_delete_from)
# Out:
# Deleted: /content/035.keras
# Deleted: /content/hanky.keras
# Deleted: /content/001.keras
# Deleted: /content/037.keras
# Deleted: /content/013.keras
# Deleted: /content/033.keras
# Deleted: /content/003.keras
# Deleted: /content/002.keras
# Deleted: /content/031.keras
# Deleted: /content/009.keras
# Deleted: /content/004.keras
# Deleted: /content/036.keras
# Deleted: /content/039.keras
# Deleted: /content/005.keras
# Deleted: /content/032.keras
# Deleted: /content/034.keras
# Deleted: /content/030.keras
# Deleted: /content/008.keras
# Deleted: /content/007.keras
# Deleted: /content/006.keras
# Deleted: /content/041.keras

# %% [markdown]
# #### 1) 체크포인트 함수 불러오기

# %%
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### 2) 모델링 체크포인트 저장

# %% [markdown]
# * 모델 선언

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(16, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.0001), loss='binary_crossentropy')

# %% [markdown]
# * 체크포인트 저장
#     * 아래 코드에서 ModelCheckpoint 콜백은 검증 데이터의 정확도(val_accuracy)를 기준으로 모델 저장
#     * 모델의 성능이 이전에 저장된 모델보다 향상될 때만 저장되도록 save_best_only=True로 설정
#     * 또한, verbose=1로 설정하면 모델이 저장될 때마다 콘솔에 메시지가 표시됨.

# %%
cp_path = '/content/{epoch:03d}.keras'  # Keras 2.11 이상 버전에서 모델 확장자 .keras
mcp = ModelCheckpoint(cp_path, monitor='val_loss', verbose = 1, save_best_only=True)

# 학습
hist = model1.fit(x_train, y_train, epochs = 50, validation_split=.2, callbacks=[mcp]).history
# Out:
# Epoch 1/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.7424
# Epoch 1: val_loss improved from inf to 0.68792, saving model to /content/001.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.7277 - val_loss: 0.6879
# Epoch 2/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - loss: 0.6719
# Epoch 2: val_loss improved from 0.68792 to 0.65524, saving model to /content/002.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6781 - val_loss: 0.6552
# Epoch 3/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6414
# Epoch 3: val_loss improved from 0.65524 to 0.63133, saving model to /content/003.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6458 - val_loss: 0.6313
# Epoch 4/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.5986
# Epoch 4: val_loss improved from 0.63133 to 0.61308, saving model to /content/004.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6094 - val_loss: 0.6131
# Epoch 5/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6769
# Epoch 5: val_loss improved from 0.61308 to 0.60147, saving model to /content/005.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6204 - val_loss: 0.6015
# Epoch 6/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6529
# Epoch 6: val_loss improved from 0.60147 to 0.59340, saving model to /content/006.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5997 - val_loss: 0.5934
# Epoch 7/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.5098
# Epoch 7: val_loss improved from 0.59340 to 0.58936, saving model to /content/007.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5623 - val_loss: 0.5894
# Epoch 8/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5672
# Epoch 8: val_loss improved from 0.58936 to 0.58819, saving model to /content/008.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5769 - val_loss: 0.5882
# Epoch 9/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5829
# Epoch 9: val_loss did not improve from 0.58819
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5788 - val_loss: 0.5885
# Epoch 10/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4201
# Epoch 10: val_loss did not improve from 0.58819
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5389 - val_loss: 0.5889
# Epoch 11/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5343
# Epoch 11: val_loss did not improve from 0.58819
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5560 - val_loss: 0.5890
# Epoch 12/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5279
# Epoch 12: val_loss did not improve from 0.58819
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5704 - val_loss: 0.5884
# Epoch 13/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6342
# Epoch 13: val_loss improved from 0.58819 to 0.58801, saving model to /content/013.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5790 - val_loss: 0.5880
# Epoch 14/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.5781
# Epoch 14: val_loss improved from 0.58801 to 0.58777, saving model to /content/014.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5665 - val_loss: 0.5878
# Epoch 15/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4420
# Epoch 15: val_loss improved from 0.58777 to 0.58760, saving model to /content/015.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5385 - val_loss: 0.5876
# Epoch 16/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6001
# Epoch 16: val_loss improved from 0.58760 to 0.58748, saving model to /content/016.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5535 - val_loss: 0.5875
# Epoch 17/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5336
# Epoch 17: val_loss improved from 0.58748 to 0.58716, saving model to /content/017.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5754 - val_loss: 0.5872
# Epoch 18/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5051
# Epoch 18: val_loss improved from 0.58716 to 0.58711, saving model to /content/018.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5446 - val_loss: 0.5871
# Epoch 19/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5800
# Epoch 19: val_loss improved from 0.58711 to 0.58705, saving model to /content/019.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5568 - val_loss: 0.5870
# Epoch 20/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3830
# Epoch 20: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5039 - val_loss: 0.5872
# Epoch 21/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6442
# Epoch 21: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5866 - val_loss: 0.5873
# Epoch 22/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5239
# Epoch 22: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5610 - val_loss: 0.5878
# Epoch 23/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.7008
# Epoch 23: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6067 - val_loss: 0.5880
# Epoch 24/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4957
# Epoch 24: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5453 - val_loss: 0.5881
# Epoch 25/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6114
# Epoch 25: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5738 - val_loss: 0.5885
# Epoch 26/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5195
# Epoch 26: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5433 - val_loss: 0.5891
# Epoch 27/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4295
# Epoch 27: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5174 - val_loss: 0.5896
# Epoch 28/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5484
# Epoch 28: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5530 - val_loss: 0.5898
# Epoch 29/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6397
# Epoch 29: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5830 - val_loss: 0.5897
# Epoch 30/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5501
# Epoch 30: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5401 - val_loss: 0.5894
# Epoch 31/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4045
# Epoch 31: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5062 - val_loss: 0.5892
# Epoch 32/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6960
# Epoch 32: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5951 - val_loss: 0.5891
# Epoch 33/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.5029
# Epoch 33: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5272 - val_loss: 0.5892
# Epoch 34/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6429
# Epoch 34: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5611 - val_loss: 0.5892
# Epoch 35/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5113
# Epoch 35: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5172 - val_loss: 0.5894
# Epoch 36/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5312
# Epoch 36: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5390 - val_loss: 0.5894
# Epoch 37/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4392
# Epoch 37: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5390 - val_loss: 0.5894
# Epoch 38/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5155
# Epoch 38: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5399 - val_loss: 0.5894
# Epoch 39/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4691
# Epoch 39: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5266 - val_loss: 0.5892
# Epoch 40/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4890
# Epoch 40: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5148 - val_loss: 0.5895
# Epoch 41/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6538
# Epoch 41: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5607 - val_loss: 0.5896
# Epoch 42/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5146
# Epoch 42: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5310 - val_loss: 0.5899
# Epoch 43/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5742
# Epoch 43: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5632 - val_loss: 0.5899
# Epoch 44/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.5063
# Epoch 44: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5336 - val_loss: 0.5902
# Epoch 45/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6040
# Epoch 45: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5499 - val_loss: 0.5906
# Epoch 46/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6113
# Epoch 46: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5694 - val_loss: 0.5907
# Epoch 47/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5639
# Epoch 47: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5374 - val_loss: 0.5912
# Epoch 48/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4890
# Epoch 48: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5347 - val_loss: 0.5913
# Epoch 49/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5371
# Epoch 49: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5302 - val_loss: 0.5915
# Epoch 50/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.4993
# Epoch 50: val_loss did not improve from 0.58705
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5499 - val_loss: 0.5910

# %%
# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## **5.[참조]가중치 규제(Regularization)**

# %%
# 규제를 위해 필요한 함수 불러오기
from keras.regularizers import l1, l2

# %% [markdown]
# ### **(1) L1 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model4 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model4.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model4.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) L2 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model5 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model5.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model5.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)
