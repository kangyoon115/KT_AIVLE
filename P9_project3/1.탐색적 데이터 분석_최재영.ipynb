# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계1 : 탐색적 데이터 분석

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **기본 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature와 중요하지 않은 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.

# %% [markdown]
# ### (2) 미션2
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project3 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/project3/'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import *

# %% [markdown]
# * 제공 함수 생성
#     * 변수 중요도를 시각화할 수 있는 함수를 제공합니다.
#     * 입력 :
#         * importance : 트리모델의 변수 중요도(예: model.feature_importances_)
#         * names : 변수 이름 목록(예 : x_train.columns
#         * result_only  : 변수 중요도 순으로 데이터프레임만 return할지, 그래프도 포함할지 결정. False이면 결과 데이터프레임 + 그래프
#         * topn : 중요도 상위 n개만 표시. all 이면 전체.
#     * 출력 :
#         * 중요도 그래프 : 중요도 내림차순으로 정렬
#         * 중요도 데이터프레임 : 중요도 내림차순으로 정렬

# %%
# 변수의 특성 중요도 계산하기
def plot_feature_importance(importance, names, result_only = False, topn = 'all'):
    feature_importance = np.array(importance)
    feature_name = np.array(names)

    data={'feature_name':feature_name,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    #변수의 특성 중요도 순으로 정렬하기
    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    #변수의 특성 중요도 그래프로 그리기
    if result_only == False :
        plt.figure(figsize=(10,20))
        sns.barplot(x='feature_importance', y='feature_name', data = fi_df)

        plt.xlabel('importance')
        plt.ylabel('feature name')
        plt.grid()

    return fi_df

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %%
data01_train = pd.read_csv(path + 'data01_train.csv')
data01_test = pd.read_csv(path + 'data01_test.csv')

# %%
data01_test.drop('subject', axis = 1, inplace = True)
data01_train.drop('subject', axis = 1, inplace = True)

# %%
display(data01_test.head())
display(data01_train.head())
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.284379          -0.021981          -0.116683         -0.992490
# 1           0.277440          -0.028086          -0.118412         -0.996620
# 2           0.305833          -0.041023          -0.087303          0.006880
# 3           0.276053          -0.016487          -0.108381         -0.995379
# 4           0.271998           0.016904          -0.078856         -0.973468
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.979640         -0.963321         -0.992563         -0.977304
# 1         -0.927676         -0.972294         -0.997346         -0.931405
# 2          0.182800         -0.237984          0.005642          0.028616
# 3         -0.983978         -0.975854         -0.995877         -0.985280
# 4         -0.702462         -0.869450         -0.979810         -0.711601
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.958142         -0.938850  ...                        -0.509523
# 1         -0.971788         -0.939837  ...                        -0.210792
# 2         -0.236474          0.016311  ...                         0.579587
# 3         -0.974907         -0.941425  ...                        -0.566291
# 4         -0.856807         -0.920760  ...                         0.447577
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.850065                    -0.018043
# 1                        -0.613367                    -0.022456
# 2                         0.394388                    -0.362616
# 3                        -0.841455                     0.289548
# 4                         0.214219                     0.010111
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.092304                          0.074220
# 1                             -0.155414                          0.247498
# 2                              0.171069                          0.576349
# 3                              0.079801                         -0.020033
# 4                              0.114179                         -0.830776
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.714534             -0.671943
# 1                             -0.112257             -0.826816
# 2                             -0.688314             -0.743234
# 3                              0.291898             -0.639435
# 4                             -0.325098             -0.840817
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  Activity
# 0             -0.018351             -0.185733   SITTING
# 1              0.184489             -0.068699  STANDING
# 2              0.272186              0.053101   WALKING
# 3             -0.111998             -0.123298   SITTING
# 4              0.116237             -0.096615  STANDING
#
# [5 rows x 562 columns]
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.965650         -0.929747  ...                        -0.487737
# 1         -0.987558         -0.937337  ...                        -0.237820
# 2         -0.995017         -0.942584  ...                        -0.535287
# 3         -0.347916          0.008288  ...                        -0.004012
# 4         -0.346372          0.584131  ...                        -0.157832
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.816696                    -0.042494
# 1                        -0.693515                    -0.062899
# 2                        -0.829311                     0.000265
# 3                        -0.408956                    -0.255125
# 4                        -0.563437                    -0.044344
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                             -0.044218                          0.307873
# 1                              0.388459                         -0.765014
# 2                             -0.525022                         -0.891875
# 3                              0.612804                          0.747381
# 4                             -0.845268                         -0.974650
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                              0.072790             -0.601120
# 1                              0.771524              0.345205
# 2                              0.021528             -0.833564
# 3                             -0.072944             -0.695819
# 4                             -0.887846             -0.705029
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)            Activity
# 0              0.331298              0.165163            STANDING
# 1             -0.769186             -0.147944              LAYING
# 2              0.202434             -0.032755            STANDING
# 3              0.287154              0.111388             WALKING
# 4              0.264952              0.137758  WALKING_DOWNSTAIRS
#
# [5 rows x 562 columns]

# %% [markdown]
# ## 2.데이터 분석 : 기본정보 살펴보기

# %% [markdown]
# ### (1) 기본정보 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - 불러온 데이터의 형태, 기초통계량, 정보 등을 확인합니다.

# %%
data01_train.shape, data01_test.shape
# Out:
# ((5881, 562), (1471, 562))

# %%
display(data01_test.describe())
display(data01_train.describe())
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        1471.000000        1471.000000        1471.000000
# mean            0.273198          -0.017281          -0.108123
# std             0.079989           0.045957           0.049082
# min            -1.000000          -1.000000          -0.418354
# 25%             0.263787          -0.024792          -0.120733
# 50%             0.277322          -0.017187          -0.108124
# 75%             0.288058          -0.010238          -0.096606
# max             0.631510           0.359587           0.543939
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       1471.000000       1471.000000       1471.000000       1471.000000
# mean          -0.614634         -0.515427         -0.607533         -0.639950
# std            0.448480          0.506094          0.424243          0.422994
# min           -0.999717         -0.999873         -1.000000         -0.999867
# 25%           -0.992669         -0.979082         -0.981070         -0.993498
# 50%           -0.952426         -0.867309         -0.869890         -0.958705
# 75%           -0.245405         -0.030639         -0.260223         -0.297260
# max            0.899922          0.782590          0.931308          0.950758
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       1471.000000       1471.000000       1471.000000  ...
# mean          -0.530760         -0.609256         -0.481055  ...
# std            0.489381          0.418536          0.542756  ...
# min           -1.000000         -0.999879         -0.948723  ...
# 25%           -0.979214         -0.980659         -0.936791  ...
# 50%           -0.873891         -0.863451         -0.890491  ...
# 75%           -0.058824         -0.256657         -0.030692  ...
# max            0.602458          0.784041          0.821218  ...
#
#        fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# count                      1471.000000                      1471.000000
# mean                          0.118651                        -0.311513
# std                           0.258112                         0.313792
# min                          -1.000000                        -0.995357
# 25%                          -0.035193                        -0.546342
# 50%                           0.135282                        -0.347433
# 75%                           0.289832                        -0.125796
# max                           0.860512                         0.941113
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      1471.000000                  1471.000000
# mean                         -0.632273                     0.009324
# std                           0.296179                     0.324864
# min                          -0.994664                    -0.937468
# 25%                          -0.844547                    -0.119166
# 50%                          -0.706699                     0.005049
# 75%                          -0.516910                     0.135698
# max                           0.894210                     0.980889
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           1471.000000                       1471.000000
# mean                               0.015666                          0.006272
# std                                0.452616                          0.608954
# min                               -0.990492                         -0.995222
# 25%                               -0.265533                         -0.485998
# 50%                                0.023421                         -0.005036
# 75%                                0.312690                          0.518184
# max                                0.991899                          0.994366
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           1471.000000           1471.000000
# mean                              -0.001510             -0.481737
# std                                0.483028              0.522714
# min                               -0.969066             -0.999380
# 25%                               -0.380300             -0.814060
# 50%                                0.002408             -0.708911
# 75%                                0.374583             -0.486534
# max                                0.979522              1.000000
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)
# count           1471.000000           1471.000000
# mean               0.055771             -0.064194
# std                0.298124              0.281645
# min               -0.995073             -1.000000
# 25%               -0.017413             -0.148445
# 50%                0.178814             -0.002243
# 75%                0.248126              0.096674
# max                0.432496              0.992766
#
# [8 rows x 561 columns]
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        5881.000000        5881.000000        5881.000000
# mean            0.274811          -0.017799          -0.109396
# std             0.067614           0.039422           0.058373
# min            -0.503823          -0.684893          -1.000000
# 25%             0.262919          -0.024877          -0.121051
# 50%             0.277154          -0.017221          -0.108781
# 75%             0.288526          -0.010920          -0.098163
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       5881.000000       5881.000000       5881.000000       5881.000000
# mean          -0.603138         -0.509815         -0.604058         -0.628151
# std            0.448807          0.501815          0.417319          0.424345
# min           -1.000000         -0.999844         -0.999667         -1.000000
# 25%           -0.992774         -0.977680         -0.980127         -0.993602
# 50%           -0.943933         -0.844575         -0.856352         -0.948501
# 75%           -0.242130         -0.034499         -0.262690         -0.291138
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       5881.000000       5881.000000       5881.000000  ...
# mean          -0.525944         -0.605374         -0.465490  ...
# std            0.485115          0.413043          0.544995  ...
# min           -0.999419         -1.000000         -1.000000  ...
# 25%           -0.977865         -0.980112         -0.936067  ...
# 50%           -0.849266         -0.849896         -0.878729  ...
# 75%           -0.068857         -0.268539         -0.013690  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# count                      5881.000000                      5881.000000
# mean                          0.126955                        -0.305883
# std                           0.249176                         0.322808
# min                          -0.965725                        -0.979261
# 25%                          -0.021610                        -0.541969
# 50%                           0.133887                        -0.342923
# 75%                           0.288944                        -0.127371
# max                           0.946700                         0.989538
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      5881.000000                  5881.000000
# mean                         -0.623548                     0.008524
# std                           0.310371                     0.339730
# min                          -0.999765                    -0.976580
# 25%                          -0.845985                    -0.122361
# 50%                          -0.712677                     0.010278
# 75%                          -0.501158                     0.154985
# max                           0.956845                     1.000000
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           5881.000000                       5881.000000
# mean                              -0.001185                          0.009340
# std                                0.447197                          0.608190
# min                               -1.000000                         -1.000000
# 25%                               -0.294369                         -0.481718
# 50%                                0.005146                          0.011448
# 75%                                0.285030                          0.499857
# max                                1.000000                          0.998702
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           5881.000000           5881.000000
# mean                              -0.007099             -0.491501
# std                                0.476738              0.509069
# min                               -1.000000             -1.000000
# 25%                               -0.373345             -0.811397
# 50%                               -0.000847             -0.709441
# 75%                                0.356236             -0.511330
# max                                0.996078              0.977344
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)
# count           5881.000000           5881.000000
# mean               0.059299             -0.054594
# std                0.297340              0.278479
# min               -1.000000             -0.980143
# 25%               -0.018203             -0.141555
# 50%                0.182893              0.003951
# 75%                0.248435              0.111932
# max                0.478157              1.000000
#
# [8 rows x 561 columns]

# %%
data01_test.info(), data01_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 6.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5881 entries, 0 to 5880
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 25.2+ MB
# (None, None)

# %%
data01_test.isnull().sum(), data01_train.isnull().sum()
# Out:
# (tBodyAcc-mean()-X                       0
#  tBodyAcc-mean()-Y                       0
#  tBodyAcc-mean()-Z                       0
#  tBodyAcc-std()-X                        0
#  tBodyAcc-std()-Y                        0
#                                         ..
#  angle(tBodyGyroJerkMean,gravityMean)    0
#  angle(X,gravityMean)                    0
#  angle(Y,gravityMean)                    0
#  angle(Z,gravityMean)                    0
#  Activity                                0
#  Length: 562, dtype: int64,
#  tBodyAcc-mean()-X                       0
#  tBodyAcc-mean()-Y                       0
#  tBodyAcc-mean()-Z                       0
#  tBodyAcc-std()-X                        0
#  tBodyAcc-std()-Y                        0
#                                         ..
#  angle(tBodyGyroJerkMean,gravityMean)    0
#  angle(X,gravityMean)                    0
#  angle(Y,gravityMean)                    0
#  angle(Z,gravityMean)                    0
#  Activity                                0
#  Length: 562, dtype: int64)

# %% [markdown]
# ### (2) 목표 변수 확인하기

# %% [markdown]
# * **세부 요구사항**
#     - target인 'Activity'에 대해 단변량 분석을 수행합니다.
#     - 범주의 종류, 범주별 빈도수 및 비율 등

# %%
data01_test['Activity'].unique()
# Out:
# array(['SITTING', 'STANDING', 'WALKING', 'WALKING_UPSTAIRS', 'LAYING',
#        'WALKING_DOWNSTAIRS'], dtype=object)

# %%
data01_test['Activity'].value_counts()
# Out:
# Activity
# LAYING                292
# STANDING              287
# SITTING               254
# WALKING               228
# WALKING_UPSTAIRS      215
# WALKING_DOWNSTAIRS    195
# Name: count, dtype: int64

# %%
data01_test['Activity'].value_counts(normalize = True) * 100
# Out:
# Activity
# LAYING                19.850442
# STANDING              19.510537
# SITTING               17.267165
# WALKING               15.499660
# WALKING_UPSTAIRS      14.615908
# WALKING_DOWNSTAIRS    13.256288
# Name: proportion, dtype: float64

# %%
data01_train['Activity'].unique()
# Out:
# array(['STANDING', 'LAYING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS', 'SITTING'], dtype=object)

# %%
data01_train['Activity'].value_counts()
# Out:
# Activity
# LAYING                1115
# STANDING              1087
# SITTING               1032
# WALKING                998
# WALKING_UPSTAIRS       858
# WALKING_DOWNSTAIRS     791
# Name: count, dtype: int64

# %%
data01_train['Activity'].value_counts(normalize = True) * 100
# Out:
# Activity
# LAYING                18.959361
# STANDING              18.483251
# SITTING               17.548036
# WALKING               16.969903
# WALKING_UPSTAIRS      14.589356
# WALKING_DOWNSTAIRS    13.450094
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3.미션1 : 데이터 분석1

# %% [markdown]
# 수많은 feature들을 모두 살펴보는 것은 과도한 시간과 노력이 필요합니다. 그래서 여러분은 **선택과 집중**을 해야 합니다.
# * 1) **트리 모델을 생성**한 후 **변수 중요도**를 구합니다.
#     * random forest 알고리즘 사용을 권장합니다.
# * 2) **중요한 feature 상위 N개를 선정**하고, 이들을 대상으로 EDA 수행.
# * 3) **각 feature 그룹별 중요도**도 파악해보며 EDA를 수행
#     * Feature 이름에는 계층구조를 담고 있습니다. 그렇다 보니 feature들을 적절하게 그룹으로 묶을 수 있습니다.
#     * 참고로, feature 그룹의 중요도는 개별 feature 중요도의 합으로 계산할 수 있습니다.

# %% [markdown]
# ### (1) 기본모델링 + 변수중요도 추출

# %% [markdown]
# * **세부 요구사항**
#     - 모델링을 위한 기본 전처리를 수행합니다.
#         - 주어진 데이터에서는 x, y로 나누고 train과 validation 분할 수행
#     - 트리기반 알고리즘을 이용하여 모델링을 합니다.
#         - 랜덤포레스트 권장 : 랜덤포레스트는 튜닝 없이 하이퍼파리미터의 기본값로도 적절한 성능의 모델을 생성할 수 있습니다.
#     - 변수 중요도 추출
#         - 사용자정의함수로 생성한 plot_feature_importance 을 이용
#         - 변수중요도 파악및 결과 저장

# %% [markdown]
# #### 1) 데이터 전처리

# %%
target = 'Activity'
x = data01_train.drop(target, axis = 1)
y = data01_train.loc[:, target]

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# #### 2) 모델링

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Validation 데이터에 대한 예측
y_pred = model.predict(x_val)

# 정확도 평가
accuracy = accuracy_score(y_val, y_pred)
classification_report = classification_report(y_val, y_pred)
print("Validation Accuracy:", accuracy)
print('-' * 55)
print("Classification Report:\n", classification_report)
# Out:
# Validation Accuracy: 0.9813084112149533
# -------------------------------------------------------
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       222
#            SITTING       0.96      0.97      0.97       198
#           STANDING       0.98      0.97      0.97       235
#            WALKING       0.99      0.97      0.98       192
# WALKING_DOWNSTAIRS       0.97      0.99      0.98       156
#   WALKING_UPSTAIRS       0.97      0.99      0.98       174
#
#           accuracy                           0.98      1177
#          macro avg       0.98      0.98      0.98      1177
#       weighted avg       0.98      0.98      0.98      1177

# %% [markdown]
# #### 3) 변수 중요도 추출

# %%
importance = model.feature_importances_
feature_names = x_train.columns
feature_importance = sorted(zip(importance, feature_names), reverse = True)

# %%
plot_feature_importance(importance, feature_names, result_only = True)
# Out:
#                            feature_name  feature_importance
# 0                  angle(X,gravityMean)            0.039039
# 1                tGravityAcc-energy()-X            0.038816
# 2                   tGravityAcc-min()-X            0.035614
# 3                   tGravityAcc-min()-Y            0.025426
# 4                  tGravityAcc-mean()-Y            0.025038
# ..                                  ...                 ...
# 556        fBodyAcc-bandsEnergy()-49,56            0.000088
# 557      fBodyAcc-bandsEnergy()-33,48.1            0.000086
# 558        fBodyAcc-bandsEnergy()-57,64            0.000079
# 559     fBodyGyro-bandsEnergy()-57,64.1            0.000069
# 560  fBodyAccJerk-bandsEnergy()-49,56.1            0.000054
#
# [561 rows x 2 columns]

# %% [markdown]
# ### (2) 중요도 기반 feature 분석

# %% [markdown]
# * **세부 요구사항**
#     - 상위 n, 하위 m 개의 변수를 선정
#     - 선정된 변수(feature)와 target 간의 관계를 kdeplot으로 그리기

# %% [markdown]
# #### 1) 상위 5, 하위 5개 변수 선정

# %%
top_features = feature_importance[:5]
for importance, feature in top_features:
    print(f"Feature: {feature}, Importance: {importance}")
# Out:
# Feature: angle(X,gravityMean), Importance: 0.03903927353563477
# Feature: tGravityAcc-energy()-X, Importance: 0.03881607027251449
# Feature: tGravityAcc-min()-X, Importance: 0.03561406445248226
# Feature: tGravityAcc-min()-Y, Importance: 0.025425990424158502
# Feature: tGravityAcc-mean()-Y, Importance: 0.025037560110398444

# %%
bottom_features = feature_importance[-5:]
for importance, feature in bottom_features:
    print(f"Feature: {feature}, Importance: {importance}")
# Out:
# Feature: fBodyAcc-bandsEnergy()-49,56, Importance: 8.756092209731571e-05
# Feature: fBodyAcc-bandsEnergy()-33,48.1, Importance: 8.567069366851691e-05
# Feature: fBodyAcc-bandsEnergy()-57,64, Importance: 7.908577791800525e-05
# Feature: fBodyGyro-bandsEnergy()-57,64.1, Importance: 6.921113385324438e-05
# Feature: fBodyAccJerk-bandsEnergy()-49,56.1, Importance: 5.399494821233639e-05

# %% [markdown]
# #### 2) 상위 5개 변수에 대한 분석

# %%
top_features = [feature for importance, feature in top_features]
sns.pairplot(data = data01_train, vars = top_features, hue = 'Activity')
plt.show()

# %%
corr_matrix_top = data01_train[top_features].corr()
sns.heatmap(corr_matrix_top, annot = True, cmap = 'coolwarm')
plt.show()

# %%
data01_train[top_features].corr()
# Out:
#                         angle(X,gravityMean)  tGravityAcc-energy()-X  \
# angle(X,gravityMean)                1.000000               -0.989484
# tGravityAcc-energy()-X             -0.989484                1.000000
# tGravityAcc-min()-X                -0.988709                0.981105
# tGravityAcc-min()-Y                 0.775699               -0.815615
# tGravityAcc-mean()-Y                0.781422               -0.820416
#
#                         tGravityAcc-min()-X  tGravityAcc-min()-Y  \
# angle(X,gravityMean)              -0.988709             0.775699
# tGravityAcc-energy()-X             0.981105            -0.815615
# tGravityAcc-min()-X                1.000000            -0.788386
# tGravityAcc-min()-Y               -0.788386             1.000000
# tGravityAcc-mean()-Y              -0.796291             0.996902
#
#                         tGravityAcc-mean()-Y
# angle(X,gravityMean)                0.781422
# tGravityAcc-energy()-X             -0.820416
# tGravityAcc-min()-X                -0.796291
# tGravityAcc-min()-Y                 0.996902
# tGravityAcc-mean()-Y                1.000000

# %% [markdown]
# #### 3) 하위 5개 변수에 대한 분석

# %%
bottom_features = [feature for importance, feature in bottom_features]
sns.pairplot(data = data01_train, vars = bottom_features, hue = 'Activity')
plt.show()

# %%
corr_matrix_bottom = data01_train[bottom_features].corr()
sns.heatmap(corr_matrix_bottom, annot = True, cmap = 'coolwarm')
plt.show()

# %%
data01_train[bottom_features].corr()
# Out:
#                                     fBodyAcc-bandsEnergy()-49,56  \
# fBodyAcc-bandsEnergy()-49,56                            1.000000
# fBodyAcc-bandsEnergy()-33,48.1                          0.594320
# fBodyAcc-bandsEnergy()-57,64                            0.868660
# fBodyGyro-bandsEnergy()-57,64.1                         0.324385
# fBodyAccJerk-bandsEnergy()-49,56.1                      0.561202
#
#                                     fBodyAcc-bandsEnergy()-33,48.1  \
# fBodyAcc-bandsEnergy()-49,56                              0.594320
# fBodyAcc-bandsEnergy()-33,48.1                            1.000000
# fBodyAcc-bandsEnergy()-57,64                              0.393055
# fBodyGyro-bandsEnergy()-57,64.1                           0.375882
# fBodyAccJerk-bandsEnergy()-49,56.1                        0.745253
#
#                                     fBodyAcc-bandsEnergy()-57,64  \
# fBodyAcc-bandsEnergy()-49,56                            0.868660
# fBodyAcc-bandsEnergy()-33,48.1                          0.393055
# fBodyAcc-bandsEnergy()-57,64                            1.000000
# fBodyGyro-bandsEnergy()-57,64.1                         0.220837
# fBodyAccJerk-bandsEnergy()-49,56.1                      0.374861
#
#                                     fBodyGyro-bandsEnergy()-57,64.1  \
# fBodyAcc-bandsEnergy()-49,56                               0.324385
# fBodyAcc-bandsEnergy()-33,48.1                             0.375882
# fBodyAcc-bandsEnergy()-57,64                               0.220837
# fBodyGyro-bandsEnergy()-57,64.1                            1.000000
# fBodyAccJerk-bandsEnergy()-49,56.1                         0.327980
#
#                                     fBodyAccJerk-bandsEnergy()-49,56.1
# fBodyAcc-bandsEnergy()-49,56                                  0.561202
# fBodyAcc-bandsEnergy()-33,48.1                                0.745253
# fBodyAcc-bandsEnergy()-57,64                                  0.374861
# fBodyGyro-bandsEnergy()-57,64.1                               0.327980
# fBodyAccJerk-bandsEnergy()-49,56.1                            1.000000

# %% [markdown]
# ## 4.미션2 : 데이터 분석2

# %% [markdown]
# 다음의 case에 맞게 feature 및 feature 그룹 중요도를 기반으로 탐색적 데이터 분석을 수행하시오.
# * Target을 **정적/동적 행동**으로 구분
#     * 6개의 행동은 2개의 그룹(정적행동, 동적행동)으로 나뉩니다.
#     * 어떤 feature(혹은 feature 그룹)이 2개 class 그룹(정적행동, 동적행동)를 구분하는데 중요한지를 찾아보고 탐색해봅시다.

# %% [markdown]
# ### (1) 정적/동적 행동으로 구분하여 분석하기

# %% [markdown]
# * **세부 요구사항**
#     - Target인 Activity를 is_dynamic 변수로 변경하시오.
#         * 값 0 : STANDING, SITTING, LAYING
#         * 값 1 : WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS
#     - is_dynamic을 예측하기 위한 기본 모델을 생성하시오.
#         * x, is_dynamic을 이용하여 train과 validation으로 데이터 분할
#         * 기본 모델링
#     - is_dynamic 을 구분하는데 중요한 변수 상위 5를 분석하시오.
#     - is_dynamic 을 구분하는데 중요한 변수 그룹을 분석하시오.
#         * sensor별
#         * sensor+agg 별

# %% [markdown]
# #### 1) is_dynamic 추가

# %%
data01_train['is_dynamic'] = data01_train['Activity'].apply(lambda x: 1 if x in ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS'] else 0)
data01_train['is_dynamic'].unique()
# Out:
# array([0, 1])

# %%
data01_train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.965650         -0.929747  ...                        -0.816696
# 1         -0.987558         -0.937337  ...                        -0.693515
# 2         -0.995017         -0.942584  ...                        -0.829311
# 3         -0.347916          0.008288  ...                        -0.408956
# 4         -0.346372          0.584131  ...                        -0.563437
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.042494                             -0.044218
# 1                    -0.062899                              0.388459
# 2                     0.000265                             -0.525022
# 3                    -0.255125                              0.612804
# 4                    -0.044344                             -0.845268
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.307873                              0.072790
# 1                         -0.765014                              0.771524
# 2                         -0.891875                              0.021528
# 3                          0.747381                             -0.072944
# 4                         -0.974650                             -0.887846
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0             -0.601120              0.331298              0.165163
# 1              0.345205             -0.769186             -0.147944
# 2             -0.833564              0.202434             -0.032755
# 3             -0.695819              0.287154              0.111388
# 4             -0.705029              0.264952              0.137758
#
#              Activity  is_dynamic
# 0            STANDING           0
# 1              LAYING           0
# 2            STANDING           0
# 3             WALKING           1
# 4  WALKING_DOWNSTAIRS           1
#
# [5 rows x 563 columns]

# %%
data01_train.drop('Activity', axis = 1, inplace = True)
data01_train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288508          -0.009196          -0.103362         -0.988986
# 1           0.265757          -0.016576          -0.098163         -0.989551
# 2           0.278709          -0.014511          -0.108717         -0.997720
# 3           0.289795          -0.035536          -0.150354         -0.231727
# 4           0.394807           0.034098           0.091229          0.088489
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.962797         -0.967422         -0.989000         -0.962596
# 1         -0.994636         -0.987435         -0.990189         -0.993870
# 2         -0.981088         -0.994008         -0.997934         -0.982187
# 3         -0.006412         -0.338117         -0.273557          0.014245
# 4         -0.106636         -0.388502         -0.010469         -0.109680
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.965650         -0.929747  ...                        -0.487737
# 1         -0.987558         -0.937337  ...                        -0.237820
# 2         -0.995017         -0.942584  ...                        -0.535287
# 3         -0.347916          0.008288  ...                        -0.004012
# 4         -0.346372          0.584131  ...                        -0.157832
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.816696                    -0.042494
# 1                        -0.693515                    -0.062899
# 2                        -0.829311                     0.000265
# 3                        -0.408956                    -0.255125
# 4                        -0.563437                    -0.044344
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                             -0.044218                          0.307873
# 1                              0.388459                         -0.765014
# 2                             -0.525022                         -0.891875
# 3                              0.612804                          0.747381
# 4                             -0.845268                         -0.974650
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                              0.072790             -0.601120
# 1                              0.771524              0.345205
# 2                              0.021528             -0.833564
# 3                             -0.072944             -0.695819
# 4                             -0.887846             -0.705029
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  is_dynamic
# 0              0.331298              0.165163           0
# 1             -0.769186             -0.147944           0
# 2              0.202434             -0.032755           0
# 3              0.287154              0.111388           1
# 4              0.264952              0.137758           1
#
# [5 rows x 562 columns]

# %% [markdown]
# #### 2) 기본모델 생성

# %%
target = 'is_dynamic'
x = data01_train.drop(target, axis = 1)
y = data01_train.loc[:, target]

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# #### 3) 변수중요도 상위 5개 분석

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Validation 데이터에 대한 예측
y_pred = model.predict(x_val)

# 정확도 평가
accuracy = accuracy_score(y_val, y_pred)

print("Validation Accuracy:", accuracy)
# Out:
# Validation Accuracy: 0.9983007646559049

# %%
importance = model.feature_importances_
feature_names = x_train.columns
feature_importance = sorted(zip(importance, feature_names), reverse = True)
print(feature_importance)
# Out:
# [(0.06999991098061836, 'fBodyAccJerk-bandsEnergy()-1,24'), (0.059819953191956016, 'tBodyAccJerkMag-sma()'), (0.04989708860766342, 'tBodyAccJerk-entropy()-X'), (0.03997422724934965, 'fBodyAccJerk-mean()-X'), (0.03997389569466526, 'tBodyAccJerk-sma()'), (0.03993990569093346, 'fBodyAccJerk-entropy()-X'), (0.03993984490690334, 'fBodyAccJerk-mad()-X'), (0.030339293588690162, 'fBodyAccJerk-bandsEnergy()-1,8'), (0.030034343881485865, 'fBodyAccJerk-max()-X'), (0.03000226087776393, 'tBodyAccJerk-iqr()-X'), (0.02996577084034262, 'tBodyAccJerkMag-mean()'), (0.02996553255771757, 'fBodyAcc-entropy()-X'), (0.02987983782246909, 'tBodyAccJerkMag-energy()'), (0.02986328257830183, 'tBodyAccJerk-iqr()-Y'), (0.02021343319053426, 'tBodyAccJerk-std()-X'), (0.02013723207107513, 'tBodyAccJerk-mad()-X'), (0.02011126128162759, 'fBodyAccJerk-energy()-X'), (0.020059848537966718, 'fBodyAccJerk-bandsEnergy()-1,16'), (0.019999822554848046, 'tBodyGyroJerk-mad()-Z'), (0.019957090396407855, 'fBodyBodyAccJerkMag-iqr()'), (0.019950360314862546, 'tBodyAccJerkMag-entropy()'), (0.019914134831935347, 'fBodyAccJerk-bandsEnergy()-9,16'), (0.019854769467617293, 'fBodyAccJerk-sma()'), (0.010127431213738235, 'fBodyAccJerk-std()-X'), (0.010077242258296832, 'tBodyAcc-max()-X'), (0.009975367109399596, 'tBodyGyroJerk-iqr()-Z'), (0.00996589949410121, 'tBodyAccJerk-entropy()-Y'), (0.00996575852883965, 'fBodyAcc-bandsEnergy()-1,24'), (0.009957501193375538, 'fBodyAcc-bandsEnergy()-9,16'), (0.00995730975498181, 'fBodyBodyAccJerkMag-entropy()'), (0.009948680626588172, 'tBodyAccJerk-mad()-Y'), (0.009948610766430435, 'fBodyAcc-sma()'), (0.00994857541097856, 'tBodyGyroJerk-sma()'), (0.009940262760568258, 'fBodyBodyAccJerkMag-mean()'), (0.009931492684688674, 'fBodyAccJerk-iqr()-X'), (0.009931435256782436, 'tBodyGyroJerkMag-sma()'), (0.009923005435958804, 'fBodyAccJerk-std()-Y'), (0.00992295008821439, 'tBodyAccJerk-mad()-Z'), (0.009922866871573937, 'fBodyAcc-entropy()-Y'), (0.009914142545957502, 'tBodyGyroJerk-iqr()-X'), (0.009906331019486493, 'tBodyAccJerk-iqr()-Z'), (0.00990591941841095, 'tBodyGyro-iqr()-Y'), (0.00990146914458558, 'fBodyAccJerk-mean()-Y'), (0.009898173057097446, 'fBodyAccJerk-bandsEnergy()-1,24.1'), (0.009897468089558485, 'fBodyAcc-bandsEnergy()-1,16'), (0.009889220156588732, 'tBodyAcc-iqr()-X'), (0.00988884013243497, 'fBodyGyro-bandsEnergy()-1,24.1'), (0.009888660010119114, 'tBodyGyro-sma()'), (0.009872698524269911, 'fBodyAccJerk-bandsEnergy()-17,24'), (0.009863636921172493, 'fBodyAccJerk-bandsEnergy()-33,40'), (0.00015317772701390042, 'tBodyAccJerk-energy()-X'), (0.00013619848036901502, 'tBodyAcc-iqr()-Y'), (0.000110205449248748, 'fBodyAcc-mad()-X'), (0.00010239550934650117, 'angle(X,gravityMean)'), (9.412327500461075e-05, 'tBodyGyroJerk-energy()-Z'), (9.411509274709489e-05, 'fBodyAccJerk-entropy()-Y'), (9.40805815890494e-05, 'fBodyBodyAccJerkMag-sma()'), (6.119710192834287e-05, 'fBodyAcc-maxInds-X'), (6.00884195410748e-05, 'fBodyGyro-std()-Z'), (5.99154779951363e-05, 'fBodyAccMag-mean()'), (5.979323046798043e-05, 'tBodyAcc-max()-Z'), (4.2746087151856675e-05, 'tBodyAcc-std()-X'), (3.450960216830622e-05, 'tBodyAccMag-entropy()'), (3.440636857508716e-05, 'fBodyAccJerk-bandsEnergy()-33,48'), (3.437326177840934e-05, 'tGravityAcc-min()-Y'), (3.428024868484025e-05, 'tGravityAcc-energy()-Y'), (3.425229208744047e-05, 'tBodyAcc-std()-Y'), (3.419532224129864e-05, 'tGravityAcc-mad()-Z'), (3.419338576702942e-05, 'tGravityAcc-mean()-X'), (3.407464150184817e-05, 'tBodyAccJerk-max()-X'), (2.7380346400444508e-05, 'tBodyGyro-mad()-Y'), (2.5816214602406265e-05, 'fBodyAccJerk-bandsEnergy()-1,8.1'), (2.5739749909311683e-05, 'fBodyAccJerk-min()-X'), (2.56920206487787e-05, 'tGravityAcc-mean()-Z'), (1.723289967166234e-05, 'fBodyGyro-bandsEnergy()-17,24'), (1.719901095684909e-05, 'tBodyGyro-min()-Z'), (1.7197508116171112e-05, 'tBodyGyroJerk-entropy()-Z'), (1.7175530710754078e-05, 'fBodyGyro-bandsEnergy()-1,8'), (1.7174728888100547e-05, 'tBodyGyroJerk-arCoeff()-X,2'), (1.7173151974812234e- ...

# %%
plot_feature_importance(importance, feature_names, result_only = True)
# Out:
#                         feature_name  feature_importance
# 0    fBodyAccJerk-bandsEnergy()-1,24            0.070000
# 1              tBodyAccJerkMag-sma()            0.059820
# 2           tBodyAccJerk-entropy()-X            0.049897
# 3              fBodyAccJerk-mean()-X            0.039974
# 4                 tBodyAccJerk-sma()            0.039974
# ..                               ...                 ...
# 556           tBodyAccMag-arCoeff()3            0.000000
# 557           tBodyAccMag-arCoeff()2            0.000000
# 558           tBodyAccMag-arCoeff()1            0.000000
# 559             tBodyAccMag-energy()            0.000000
# 560             angle(Z,gravityMean)            0.000000
#
# [561 rows x 2 columns]

# %%
top_features = feature_importance[:5]
for importance, feature in top_features:
    print(f"Feature: {feature}, Importance: {importance}")
# Out:
# Feature: fBodyAccJerk-bandsEnergy()-1,24, Importance: 0.06999991098061836
# Feature: tBodyAccJerkMag-sma(), Importance: 0.059819953191956016
# Feature: tBodyAccJerk-entropy()-X, Importance: 0.04989708860766342
# Feature: fBodyAccJerk-mean()-X, Importance: 0.03997422724934965
# Feature: tBodyAccJerk-sma(), Importance: 0.03997389569466526

# %%
top_features = [feature for importance, feature in top_features]
sns.pairplot(data = data01_train, vars = top_features, hue = 'is_dynamic')
plt.show()

# %%
corr_matrix_top = data01_train[top_features].corr()
sns.heatmap(corr_matrix_top, annot = True, cmap = 'coolwarm')
plt.show()

# %%
data01_train[top_features].corr()
# Out:
#                                  fBodyAccJerk-bandsEnergy()-1,24  \
# fBodyAccJerk-bandsEnergy()-1,24                         1.000000
# tBodyAccJerkMag-sma()                                   0.920624
# tBodyAccJerk-entropy()-X                                0.748235
# fBodyAccJerk-mean()-X                                   0.942392
# tBodyAccJerk-sma()                                      0.918274
#
#                                  tBodyAccJerkMag-sma()  \
# fBodyAccJerk-bandsEnergy()-1,24               0.920624
# tBodyAccJerkMag-sma()                         1.000000
# tBodyAccJerk-entropy()-X                      0.919590
# fBodyAccJerk-mean()-X                         0.984695
# tBodyAccJerk-sma()                            0.999654
#
#                                  tBodyAccJerk-entropy()-X  \
# fBodyAccJerk-bandsEnergy()-1,24                  0.748235
# tBodyAccJerkMag-sma()                            0.919590
# tBodyAccJerk-entropy()-X                         1.000000
# fBodyAccJerk-mean()-X                            0.901229
# tBodyAccJerk-sma()                               0.918449
#
#                                  fBodyAccJerk-mean()-X  tBodyAccJerk-sma()
# fBodyAccJerk-bandsEnergy()-1,24               0.942392            0.918274
# tBodyAccJerkMag-sma()                         0.984695            0.999654
# tBodyAccJerk-entropy()-X                      0.901229            0.918449
# fBodyAccJerk-mean()-X                         1.000000            0.982560
# tBodyAccJerk-sma()                            0.982560            1.000000

# %%
feature_importance
# Out:
# [(0.06999991098061836, 'fBodyAccJerk-bandsEnergy()-1,24'),
#  (0.059819953191956016, 'tBodyAccJerkMag-sma()'),
#  (0.04989708860766342, 'tBodyAccJerk-entropy()-X'),
#  (0.03997422724934965, 'fBodyAccJerk-mean()-X'),
#  (0.03997389569466526, 'tBodyAccJerk-sma()'),
#  (0.03993990569093346, 'fBodyAccJerk-entropy()-X'),
#  (0.03993984490690334, 'fBodyAccJerk-mad()-X'),
#  (0.030339293588690162, 'fBodyAccJerk-bandsEnergy()-1,8'),
#  (0.030034343881485865, 'fBodyAccJerk-max()-X'),
#  (0.03000226087776393, 'tBodyAccJerk-iqr()-X'),
#  (0.02996577084034262, 'tBodyAccJerkMag-mean()'),
#  (0.02996553255771757, 'fBodyAcc-entropy()-X'),
#  (0.02987983782246909, 'tBodyAccJerkMag-energy()'),
#  (0.02986328257830183, 'tBodyAccJerk-iqr()-Y'),
#  (0.02021343319053426, 'tBodyAccJerk-std()-X'),
#  (0.02013723207107513, 'tBodyAccJerk-mad()-X'),
#  (0.02011126128162759, 'fBodyAccJerk-energy()-X'),
#  (0.020059848537966718, 'fBodyAccJerk-bandsEnergy()-1,16'),
#  (0.019999822554848046, 'tBodyGyroJerk-mad()-Z'),
#  (0.019957090396407855, 'fBodyBodyAccJerkMag-iqr()'),
#  (0.019950360314862546, 'tBodyAccJerkMag-entropy()'),
#  (0.019914134831935347, 'fBodyAccJerk-bandsEnergy()-9,16'),
#  (0.019854769467617293, 'fBodyAccJerk-sma()'),
#  (0.010127431213738235, 'fBodyAccJerk-std()-X'),
#  (0.010077242258296832, 'tBodyAcc-max()-X'),
#  (0.009975367109399596, 'tBodyGyroJerk-iqr()-Z'),
#  (0.00996589949410121, 'tBodyAccJerk-entropy()-Y'),
#  (0.00996575852883965, 'fBodyAcc-bandsEnergy()-1,24'),
#  (0.009957501193375538, 'fBodyAcc-bandsEnergy()-9,16'),
#  (0.00995730975498181, 'fBodyBodyAccJerkMag-entropy()'),
#  (0.009948680626588172, 'tBodyAccJerk-mad()-Y'),
#  (0.009948610766430435, 'fBodyAcc-sma()'),
#  (0.00994857541097856, 'tBodyGyroJerk-sma()'),
#  (0.009940262760568258, 'fBodyBodyAccJerkMag-mean()'),
#  (0.009931492684688674, 'fBodyAccJerk-iqr()-X'),
#  (0.009931435256782436, 'tBodyGyroJerkMag-sma()'),
#  (0.009923005435958804, 'fBodyAccJerk-std()-Y'),
#  (0.00992295008821439, 'tBodyAccJerk-mad()-Z'),
#  (0.009922866871573937, 'fBodyAcc-entropy()-Y'),
#  (0.009914142545957502, 'tBodyGyroJerk-iqr()-X'),
#  (0.009906331019486493, 'tBodyAccJerk-iqr()-Z'),
#  (0.00990591941841095, 'tBodyGyro-iqr()-Y'),
#  (0.00990146914458558, 'fBodyAccJerk-mean()-Y'),
#  (0.009898173057097446, 'fBodyAccJerk-bandsEnergy()-1,24.1'),
#  (0.009897468089558485, 'fBodyAcc-bandsEnergy()-1,16'),
#  (0.009889220156588732, 'tBodyAcc-iqr()-X'),
#  (0.00988884013243497, 'fBodyGyro-bandsEnergy()-1,24.1'),
#  (0.009888660010119114, 'tBodyGyro-sma()'),
#  (0.009872698524269911, 'fBodyAccJerk-bandsEnergy()-17,24'),
#  (0.009863636921172493, 'fBodyAccJerk-bandsEnergy()-33,40'),
#  (0.00015317772701390042, 'tBodyAccJerk-energy()-X'),
#  (0.00013619848036901502, 'tBodyAcc-iqr()-Y'),
#  (0.000110205449248748, 'fBodyAcc-mad()-X'),
#  (0.00010239550934650117, 'angle(X,gravityMean)'),
#  (9.412327500461075e-05, 'tBodyGyroJerk-energy()-Z'),
#  (9.411509274709489e-05, 'fBodyAccJerk-entropy()-Y'),
#  (9.40805815890494e-05, 'fBodyBodyAccJerkMag-sma()'),
#  (6.119710192834287e-05, 'fBodyAcc-maxInds-X'),
#  (6.00884195410748e-05, 'fBodyGyro-std()-Z'),
#  (5.99154779951363e-05, 'fBodyAccMag-mean()'),
#  (5.979323046798043e-05, 'tBodyAcc-max()-Z'),
#  (4.2746087151856675e-05, 'tBodyAcc-std()-X'),
#  (3.450960216830622e-05, 'tBodyAccMag-entropy()'),
#  (3.440636857508716e-05, 'fBodyAccJerk-bandsEnergy()-33,48'),
#  (3.437326177840934e-05, 'tGravityAcc-min()-Y'),
#  (3.428024868484025e-05, 'tGravityAcc-energy()-Y'),
#  (3.425229208744047e-05, 'tBodyAcc-std()-Y'),
#  (3.419532224129864e-05, 'tGravityAcc-mad()-Z'),
#  (3.419338576702942e-05, 'tGravityAcc-mean()-X'),
#  (3.407464150184817e-05, 'tBodyAccJerk-max()-X'),
#  (2.7380346400444508e-05, 'tBodyGyro-mad()-Y'),
#  (2.5816214602406265e-05, 'fBodyAccJerk-bandsEnergy()-1,8.1'),
#  (2.5739749909311683e-05, 'fBodyAccJerk-min()-X'),
#  (2.56920206487787e-05, 'tGravityAcc-mean()-Z'),
#  (1.723289967166234e-05, 'fBodyGyro-bandsEnergy()-17,24'),
#  (1.719901095684909e-05, 'tBodyGyro-min()-Z'),
#  (1.7197508116171112e-05, 'tBodyGyroJerk-entropy()-Z'),
#  (1.7175530710754078e-05, 'fBodyGyro-bandsEnergy()-1,8'),
#  (1.7174728888100547e-05, 'tBodyGyroJerk-arCoeff()-X,2'),
#  (1.7173151974812234e-05, 'fBodyAccJerk-meanFreq()-X'),
#  (1.7170447034311044e-05, 'fBodyGyro-bandsEnergy()-1,24'),
#  (1.714754159269189e-05, 'fBodyGyro-std()-X'),
#  (1.7144943192686514e-05, 'tBodyGyroJerk-arCoeff()-Y,4'),
#  (1.7143001296529373e-05, 'fBodyAccMag-entropy()'),
#  (1.7140833225231137e-05, 'tGravityAcc-std()-Y'),
#  (1.7107445229990236e-05, 'tBodyGyroJerk-std()-Z'),
#  (1.7087953374299016e-05, 'fBodyGyro-bandsEnergy()-17,32'),
#  (1.707812953819344e-05, 'tBodyGyroMag-mad()'),
#  (1.611740776627989e-05, 'tBodyGyroMag-entropy()'),
#  (1.2890505361824626e-05, 'tBodyAcc-energy()-X'),
#  (1.0713665804000529e-05, 'fBodyGyro-bandsEnergy()-9,16.2'),
#  (8.623259262028818e-06, 'tBodyAccJerk-min()-X'),
#  (8.622368936390205e-06, 'tBodyGyro-entropy()-Y'),
#  (8.618851098354117e-06, 'tGravityAcc-std()-Z'),
#  (8.595699518903553e-06, 'tGravityAcc-arCoeff()-X,4'),
#  (8.59492051891117e-06, 'tBodyGyroJerkMag-mean()'),
#  (8.594138976228342e-06, 'fBodyAcc-std()-Y'),
#  (8.591837316190133e-06, 'tBodyAcc-mad()-Y'),
#  (8.59105415929479e-06, 'fBodyBodyGyroJerkMag-max()'),
#  (8.585827981184225e-06, 'tGravityAcc-iqr()-X'),
#  (8.580741052060316e-06, 'tGravityAcc-energy()-Z'),
#  (8.579316915662477e-06, 'fBodyGyro-max()-X'),
#  (8.575793825359884e-06, 'tBodyGyro-energy()-Z'),
#  (8.575120485832071e-06, 'fBodyAccJerk-bandsEnergy()-41,48'),
#  (8.572665060481562e-06, 'fBodyAccJerk-bandsEnergy()-9,16.1'),
#  (8.56970713375442e-06, 'tGravityAcc-max()-X'),
#  (8.568384677203147e-06, 'fBodyGyro-energy()-X'),
#  (8.559742538655187e-06, 'fBodyAccJerk-energy()-Y'),
#  (8.555891396927778e-06, 'tBodyAcc-mean()-Z'),
#  (7.710499308375356e-06, 'tBodyGyroMag-arCoeff()4'),
#  (6.88235600720204e-06, 'fBodyBodyGyroMag-mean()'),
#  (6.8611247599052995e-06, 'fBodyAccJerk-bandsEnergy()-1,8.2'),
#  (6.8323941030658055e-06, 'fBodyAcc-bandsEnergy()-49,56.1'),
#  (6.489561242750977e-06, 'fBodyGyro-bandsEnergy()-57,64'),
#  (5.751022888007449e-06, 'tBodyAccJerk-mean()-X'),
#  (5.723188567930836e-06, 'tBodyAccMag-iqr()'),
#  (2.8722301452853584e-06, 'fBodyAccJerk-bandsEnergy()-41,48.1'),
#  (2.8582655585473527e-06, 'fBodyGyro-bandsEnergy()-49,64.1'),
#  (1.7164923613200016e-06, 'fBodyAccMag-maxInds'),
#  (8.533637676982818e-07, 'fBodyGyro-mad()-X'),
#  (0.0, 'tGravityAccMag-std()'),
#  (0.0, 'tGravityAccMag-sma()'),
#  (0.0, 'tGravityAccMag-min()'),
#  (0.0, 'tGravityAccMag-mean()'),
#  (0.0, 'tGravityAccMag-max()'),
#  (0.0, 'tGravityAccMag-mad()'),
#  (0.0, 'tGravityAccMag-iqr()'),
#  (0.0, 'tGravityAccMag-entropy()'),
#  (0.0, 'tGravityAccMag-energy()'),
#  (0.0, 'tGravityAccMag-arCoeff()4'),
#  (0.0, 'tGravityAccMag-arCoeff()3'),
#  (0.0, 'tGravityAccMag-arCoeff()2'),
#  (0.0, 'tGravityAccMag-arCoeff()1'),
#  (0.0, 'tGravityAcc-std()-X'),
#  (0.0, 'tGravityAcc-sma()'),
#  (0.0, 'tGravityAcc-min()-Z'),
#  (0.0, 'tGravityAcc-min()-X'),
#  (0.0, 'tGravityAcc-mean()-Y'),
#  (0.0, 'tGravityAcc-max()-Z'),
#  (0.0, 'tGravityAcc-max()-Y'),
#  (0.0, 'tGravityAcc-mad()-Y'),
#  (0.0, 'tGravityAcc-mad()-X'),
#  (0.0, 'tGravityAcc-iqr()-Z'),
#  (0.0, 'tGravityAcc-iqr()-Y'),
#  (0.0, 'tGravityAcc-entropy()-Z'),
#  (0.0, 'tGravityAcc-entropy()-Y'),
#  (0.0, 'tGravityAcc-entropy()-X'),
#  (0.0, 'tGravityAcc-energy()-X'),
#  (0.0, 'tGravityAcc-correlation()-Y,Z'),
#  (0.0, 'tGravityAcc-correlation()-X,Z'),
#  (0.0, 'tGravityAcc-correlation()-X,Y'),
#  (0.0, 'tGravityAcc-arCoeff()-Z,4'),
#  (0.0, 'tGravityAcc-arCoeff()-Z,3'),
#  (0.0, 'tGravityAcc-arCoeff()-Z,2'),
#  (0.0, 'tGravityAcc-arCoeff()-Z,1'),
#  (0.0, 'tGravityAcc-arCoeff()-Y,4'),
#  (0.0, 'tGravityAcc-arCoeff()-Y,3'),
#  (0.0, 'tGravityAcc-arCoeff()-Y,2'),
#  (0.0, 'tGravityAcc-arCoeff()-Y,1'),
#  (0.0, 'tGravityAcc-arCoeff()-X,3'),
#  (0.0, 'tGravityAcc-arCoeff()-X,2'),
#  (0.0, 'tGravityAcc-arCoeff()-X,1'),
#  (0.0, 'tBodyGyroMag-std()'),
#  (0.0, 'tBodyGyroMag-sma()'),
#  (0.0, 'tBodyGyroMag-min()'),
#  (0.0, 'tBodyGyroMag-mean()'),
#  (0.0, 'tBodyGyroMag-max()'),
#  (0.0, 'tBodyGyroMag-iqr()'),
#  (0.0, 'tBodyGyroMag-energy()'),
#  (0.0, 'tBodyGyroMag-arCoeff()3'),
#  (0.0, 'tBodyGyroMag-arCoeff()2'),
#  (0.0, 'tBodyGyroMag-arCoeff()1'),
#  (0.0, 'tBodyGyroJerkMag-std()'),
#  (0.0, 'tBodyGyroJerkMag-min()'),
#  (0.0, 'tBodyGyroJerkMag-max()'),
#  (0.0, 'tBodyGyroJerkMag-mad()'),
#  (0.0, 'tBodyGyroJerkMag-iqr()'),
#  (0.0, 'tBodyGyroJerkMag-entropy()'),
#  (0.0, 'tBodyGyroJerkMag-energy()'),
#  (0.0, 'tBodyGyroJerkMag-arCoeff()4'),
#  (0.0, 'tBodyGyroJerkMag-arCoeff()3'),
#  (0.0, 'tBodyGyroJerkMag-arCoeff()2'),
#  (0.0, 'tBodyGyroJerkMag-arCoeff()1'),
#  (0.0, 'tBodyGyroJerk-std()-Y'),
#  (0.0, 'tBodyGyroJerk-std()-X'),
#  (0.0, 'tBodyGyroJerk-min()-Z'),
#  (0.0, 'tBodyGyroJerk-min()-Y'),
#  (0.0, 'tBodyGyroJerk-min()-X'),
#  (0.0, 'tBodyGyroJerk-mean()-Z'),
#  (0.0, 'tBodyGyroJerk-mean()-Y'),
#  (0.0, 'tBodyGyroJerk-mean()-X'),
#  (0.0, 'tBodyGyroJerk-max()-Z'),
#  (0.0, 'tBodyGyroJerk-max()-Y'),
#  (0.0, 'tBodyGyroJerk-max()-X'),
#  (0.0, 'tBodyGyroJerk-mad()-Y'),
#  (0.0, 'tBodyGyroJerk-mad()-X'),
#  (0.0, 'tBodyGyroJerk-iqr()-Y'),
#  (0.0, 'tBodyGyroJerk-entropy()-Y'),
#  (0.0, 'tBodyGyroJerk-entropy()-X'),
#  (0.0, 'tBodyGyroJerk-energy()-Y'),
#  (0.0, 'tBodyGyroJerk-energy()-X'),
#  (0.0, 'tBodyGyroJerk-correlation()-Y,Z'),
#  (0.0, 'tBodyGyroJerk-correlation()-X,Z'),
#  (0.0, 'tBodyGyroJerk-correlation()-X,Y'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-Z,4'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-Z,3'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-Z,2'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-Z,1'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-Y,3'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-Y,2'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-Y,1'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-X,4'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-X,3'),
#  (0.0, 'tBodyGyroJerk-arCoeff()-X,1'),
#  (0.0, 'tBodyGyro-std()-Z'),
#  (0.0, 'tBodyGyro-std()-Y'),
#  (0.0, 'tBodyGyro-std()-X'),
#  (0.0, 'tBodyGyro-min()-Y'),
#  (0.0, 'tBodyGyro-min()-X'),
#  (0.0, 'tBodyGyro-mean()-Z'),
#  (0.0, 'tBodyGyro-mean()-Y'),
#  (0.0, 'tBodyGyro-mean()-X'),
#  (0.0, 'tBodyGyro-max()-Z'),
#  (0.0, 'tBodyGyro-max()-Y'),
#  (0.0, 'tBodyGyro-max()-X'),
#  (0.0, 'tBodyGyro-mad()-Z'),
#  (0.0, 'tBodyGyro-mad()-X'),
#  (0.0, 'tBodyGyro-iqr()-Z'),
#  (0.0, 'tBodyGyro-iqr()-X'),
#  (0.0, 'tBodyGyro-entropy()-Z'),
#  (0.0, 'tBodyGyro-entropy()-X'),
#  (0.0, 'tBodyGyro-energy()-Y'),
#  (0.0, 'tBodyGyro-energy()-X'),
#  (0.0, 'tBodyGyro-correlation()-Y,Z'),
#  (0.0, 'tBodyGyro-correlation()-X,Z'),
#  (0.0, 'tBodyGyro-correlation()-X,Y'),
#  (0.0, 'tBodyGyro-arCoeff()-Z,4'),
#  (0.0, 'tBodyGyro-arCoeff()-Z,3'),
#  (0.0, 'tBodyGyro-arCoeff()-Z,2'),
#  (0.0, 'tBodyGyro-arCoeff()-Z,1'),
#  (0.0, 'tBodyGyro-arCoeff()-Y,4'),
#  (0.0, 'tBodyGyro-arCoeff()-Y,3'),
#  (0.0, 'tBodyGyro-arCoeff()-Y,2'),
#  (0.0, 'tBodyGyro-arCoeff()-Y,1'),
#  (0.0, 'tBodyGyro-arCoeff()-X,4'),
#  (0.0, 'tBodyGyro-arCoeff()-X,3'),
#  (0.0, 'tBodyGyro-arCoeff()-X,2'),
#  (0.0, 'tBodyGyro-arCoeff()-X,1'),
#  (0.0, 'tBodyAccMag-std()'),
#  (0.0, 'tBodyAccMag-sma()'),
#  (0.0, 'tBodyAccMag-min()'),
#  (0.0, 'tBodyAccMag-mean()'),
#  (0.0, 'tBodyAccMag-max()'),
#  (0.0, 'tBodyAccMag-mad()'),
#  (0.0, 'tBodyAccMag-energy()'),
#  (0.0, 'tBodyAccMag-arCoeff()4'),
#  (0.0, 'tBodyAccMag-arCoeff()3'),
#  (0.0, 'tBodyAccMag-arCoeff()2'),
#  (0.0, 'tBodyAccMag-arCoeff()1'),
#  (0.0, 'tBodyAccJerkMag-std()'),
#  (0.0, 'tBodyAccJerkMag-min()'),
#  (0.0, 'tBodyAccJerkMag-max()'),
#  (0.0, 'tBodyAccJerkMag-mad()'),
#  (0.0, 'tBodyAccJerkMag-iqr()'),
#  (0.0, 'tBodyAccJerkMag-arCoeff()4'),
#  (0.0, 'tBodyAccJerkMag-arCoeff()3'),
#  (0.0, 'tBodyAccJerkMag-arCoeff()2'),
#  (0.0, 'tBodyAccJerkMag-arCoeff()1'),
#  (0.0, 'tBodyAccJerk-std()-Z'),
#  (0.0, 'tBodyAccJerk-std()-Y'),
#  (0.0, 'tBodyAccJerk-min()-Z'),
#  (0.0, 'tBodyAccJerk-min()-Y'),
#  (0.0, 'tBodyAccJerk-mean()-Z'),
#  (0.0, 'tBodyAccJerk-mean()-Y'),
#  (0.0, 'tBodyAccJerk-max()-Z'),
#  (0.0, 'tBodyAccJerk-max()-Y'),
#  (0.0, 'tBodyAccJerk-entropy()-Z'),
#  (0.0, 'tBodyAccJerk-energy()-Z'),
#  (0.0, 'tBodyAccJerk-energy()-Y'),
#  (0.0, 'tBodyAccJerk-correlation()-Y,Z'),
#  (0.0, 'tBodyAccJerk-correlation()-X,Z'),
#  (0.0, 'tBodyAccJerk-correlation()-X,Y'),
#  (0.0, 'tBodyAccJerk-arCoeff()-Z,4'),
#  (0.0, 'tBodyAccJerk-arCoeff()-Z,3'),
#  (0.0, 'tBodyAccJerk-arCoeff()-Z,2'),
#  (0.0, 'tBodyAccJerk-arCoeff()-Z,1'),
#  (0.0, 'tBodyAccJerk-arCoeff()-Y,4'),
#  (0.0, 'tBodyAccJerk-arCoeff()-Y,3'),
#  (0.0, 'tBodyAccJerk-arCoeff()-Y,2'),
#  (0.0, 'tBodyAccJerk-arCoeff()-Y,1'),
#  (0.0, 'tBodyAccJerk-arCoeff()-X,4'),
#  (0.0, 'tBodyAccJerk-arCoeff()-X,3'),
#  (0.0, 'tBodyAccJerk-arCoeff()-X,2'),
#  (0.0, 'tBodyAccJerk-arCoeff()-X,1'),
#  (0.0, 'tBodyAcc-std()-Z'),
#  (0.0, 'tBodyAcc-sma()'),
#  (0.0, 'tBodyAcc-min()-Z'),
#  (0.0, 'tBodyAcc-min()-Y'),
#  (0.0, 'tBodyAcc-min()-X'),
#  (0.0, 'tBodyAcc-mean()-Y'),
#  (0.0, 'tBodyAcc-mean()-X'),
#  (0.0, 'tBodyAcc-max()-Y'),
#  (0.0, 'tBodyAcc-mad()-Z'),
#  (0.0, 'tBodyAcc-mad()-X'),
#  (0.0, 'tBodyAcc-iqr()-Z'),
#  (0.0, 'tBodyAcc-entropy()-Z'),
#  (0.0, 'tBodyAcc-entropy()-Y'),
#  (0.0, 'tBodyAcc-entropy()-X'),
#  (0.0, 'tBodyAcc-energy()-Z'),
#  (0.0, 'tBodyAcc-energy()-Y'),
#  (0.0, 'tBodyAcc-correlation()-Y,Z'),
#  (0.0, 'tBodyAcc-correlation()-X,Z'),
#  (0.0, 'tBodyAcc-correlation()-X,Y'),
#  (0.0, 'tBodyAcc-arCoeff()-Z,4'),
#  (0.0, 'tBodyAcc-arCoeff()-Z,3'),
#  (0.0, 'tBodyAcc-arCoeff()-Z,2'),
#  (0.0, 'tBodyAcc-arCoeff()-Z,1'),
#  (0.0, 'tBodyAcc-arCoeff()-Y,4'),
#  (0.0, 'tBodyAcc-arCoeff()-Y,3'),
#  (0.0, 'tBodyAcc-arCoeff()-Y,2'),
#  (0.0, 'tBodyAcc-arCoeff()-Y,1'),
#  (0.0, 'tBodyAcc-arCoeff()-X,4'),
#  (0.0, 'tBodyAcc-arCoeff()-X,3'),
#  (0.0, 'tBodyAcc-arCoeff()-X,2'),
#  (0.0, 'tBodyAcc-arCoeff()-X,1'),
#  (0.0, 'fBodyGyro-std()-Y'),
#  (0.0, 'fBodyGyro-sma()'),
#  (0.0, 'fBodyGyro-skewness()-Z'),
#  (0.0, 'fBodyGyro-skewness()-Y'),
#  (0.0, 'fBodyGyro-skewness()-X'),
#  (0.0, 'fBodyGyro-min()-Z'),
#  (0.0, 'fBodyGyro-min()-Y'),
#  (0.0, 'fBodyGyro-min()-X'),
#  (0.0, 'fBodyGyro-meanFreq()-Z'),
#  (0.0, 'fBodyGyro-meanFreq()-Y'),
#  (0.0, 'fBodyGyro-meanFreq()-X'),
#  (0.0, 'fBodyGyro-mean()-Z'),
#  (0.0, 'fBodyGyro-mean()-Y'),
#  (0.0, 'fBodyGyro-mean()-X'),
#  (0.0, 'fBodyGyro-maxInds-Z'),
#  (0.0, 'fBodyGyro-maxInds-Y'),
#  (0.0, 'fBodyGyro-maxInds-X'),
#  (0.0, 'fBodyGyro-max()-Z'),
#  (0.0, 'fBodyGyro-max()-Y'),
#  (0.0, 'fBodyGyro-mad()-Z'),
#  (0.0, 'fBodyGyro-mad()-Y'),
#  (0.0, 'fBodyGyro-kurtosis()-Z'),
#  (0.0, 'fBodyGyro-kurtosis()-Y'),
#  (0.0, 'fBodyGyro-kurtosis()-X'),
#  (0.0, 'fBodyGyro-iqr()-Z'),
#  (0.0, 'fBodyGyro-iqr()-Y'),
#  (0.0, 'fBodyGyro-iqr()-X'),
#  (0.0, 'fBodyGyro-entropy()-Z'),
#  (0.0, 'fBodyGyro-entropy()-Y'),
#  (0.0, 'fBodyGyro-entropy()-X'),
#  (0.0, 'fBodyGyro-energy()-Z'),
#  (0.0, 'fBodyGyro-energy()-Y'),
#  (0.0, 'fBodyGyro-bandsEnergy()-9,16.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-9,16'),
#  (0.0, 'fBodyGyro-bandsEnergy()-57,64.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-57,64.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-49,64.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-49,64'),
#  (0.0, 'fBodyGyro-bandsEnergy()-49,56.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-49,56.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-49,56'),
#  (0.0, 'fBodyGyro-bandsEnergy()-41,48.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-41,48.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-41,48'),
#  (0.0, 'fBodyGyro-bandsEnergy()-33,48.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-33,48.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-33,48'),
#  (0.0, 'fBodyGyro-bandsEnergy()-33,40.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-33,40.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-33,40'),
#  (0.0, 'fBodyGyro-bandsEnergy()-25,48.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-25,48.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-25,48'),
#  (0.0, 'fBodyGyro-bandsEnergy()-25,32.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-25,32.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-25,32'),
#  (0.0, 'fBodyGyro-bandsEnergy()-17,32.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-17,32.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-17,24.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-17,24.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-1,8.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-1,8.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-1,24.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-1,16.2'),
#  (0.0, 'fBodyGyro-bandsEnergy()-1,16.1'),
#  (0.0, 'fBodyGyro-bandsEnergy()-1,16'),
#  (0.0, 'fBodyBodyGyroMag-std()'),
#  (0.0, 'fBodyBodyGyroMag-sma()'),
#  (0.0, 'fBodyBodyGyroMag-skewness()'),
#  (0.0, 'fBodyBodyGyroMag-min()'),
#  (0.0, 'fBodyBodyGyroMag-meanFreq()'),
#  (0.0, 'fBodyBodyGyroMag-maxInds'),
#  (0.0, 'fBodyBodyGyroMag-max()'),
#  (0.0, 'fBodyBodyGyroMag-mad()'),
#  (0.0, 'fBodyBodyGyroMag-kurtosis()'),
#  (0.0, 'fBodyBodyGyroMag-iqr()'),
#  (0.0, 'fBodyBodyGyroMag-entropy()'),
#  (0.0, 'fBodyBodyGyroMag-energy()'),
#  (0.0, 'fBodyBodyGyroJerkMag-std()'),
#  (0.0, 'fBodyBodyGyroJerkMag-sma()'),
#  (0.0, 'fBodyBodyGyroJerkMag-skewness()'),
#  (0.0, 'fBodyBodyGyroJerkMag-min()'),
#  (0.0, 'fBodyBodyGyroJerkMag-meanFreq()'),
#  (0.0, 'fBodyBodyGyroJerkMag-mean()'),
#  (0.0, 'fBodyBodyGyroJerkMag-maxInds'),
#  (0.0, 'fBodyBodyGyroJerkMag-mad()'),
#  (0.0, 'fBodyBodyGyroJerkMag-kurtosis()'),
#  (0.0, 'fBodyBodyGyroJerkMag-iqr()'),
#  (0.0, 'fBodyBodyGyroJerkMag-entropy()'),
#  (0.0, 'fBodyBodyGyroJerkMag-energy()'),
#  (0.0, 'fBodyBodyAccJerkMag-std()'),
#  (0.0, 'fBodyBodyAccJerkMag-skewness()'),
#  (0.0, 'fBodyBodyAccJerkMag-min()'),
#  (0.0, 'fBodyBodyAccJerkMag-meanFreq()'),
#  (0.0, 'fBodyBodyAccJerkMag-maxInds'),
#  (0.0, 'fBodyBodyAccJerkMag-max()'),
#  (0.0, 'fBodyBodyAccJerkMag-mad()'),
#  (0.0, 'fBodyBodyAccJerkMag-kurtosis()'),
#  (0.0, 'fBodyBodyAccJerkMag-energy()'),
#  (0.0, 'fBodyAccMag-std()'),
#  (0.0, 'fBodyAccMag-sma()'),
#  (0.0, 'fBodyAccMag-skewness()'),
#  (0.0, 'fBodyAccMag-min()'),
#  (0.0, 'fBodyAccMag-meanFreq()'),
#  (0.0, 'fBodyAccMag-max()'),
#  (0.0, 'fBodyAccMag-mad()'),
#  (0.0, 'fBodyAccMag-kurtosis()'),
#  (0.0, 'fBodyAccMag-iqr()'),
#  (0.0, 'fBodyAccMag-energy()'),
#  (0.0, 'fBodyAccJerk-std()-Z'),
#  (0.0, 'fBodyAccJerk-skewness()-Z'),
#  (0.0, 'fBodyAccJerk-skewness()-Y'),
#  (0.0, 'fBodyAccJerk-skewness()-X'),
#  (0.0, 'fBodyAccJerk-min()-Z'),
#  (0.0, 'fBodyAccJerk-min()-Y'),
#  (0.0, 'fBodyAccJerk-meanFreq()-Z'),
#  (0.0, 'fBodyAccJerk-meanFreq()-Y'),
#  (0.0, 'fBodyAccJerk-mean()-Z'),
#  (0.0, 'fBodyAccJerk-maxInds-Z'),
#  (0.0, 'fBodyAccJerk-maxInds-Y'),
#  (0.0, 'fBodyAccJerk-maxInds-X'),
#  (0.0, 'fBodyAccJerk-max()-Z'),
#  (0.0, 'fBodyAccJerk-max()-Y'),
#  (0.0, 'fBodyAccJerk-mad()-Z'),
#  (0.0, 'fBodyAccJerk-mad()-Y'),
#  (0.0, 'fBodyAccJerk-kurtosis()-Z'),
#  (0.0, 'fBodyAccJerk-kurtosis()-Y'),
#  (0.0, 'fBodyAccJerk-kurtosis()-X'),
#  (0.0, 'fBodyAccJerk-iqr()-Z'),
#  (0.0, 'fBodyAccJerk-iqr()-Y'),
#  (0.0, 'fBodyAccJerk-entropy()-Z'),
#  (0.0, 'fBodyAccJerk-energy()-Z'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-9,16.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-57,64.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-57,64.1'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-57,64'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-49,64.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-49,64.1'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-49,64'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-49,56.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-49,56.1'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-49,56'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-41,48.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-33,48.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-33,48.1'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-33,40.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-33,40.1'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-25,48.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-25,48.1'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-25,48'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-25,32.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-25,32.1'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-25,32'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-17,32.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-17,32.1'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-17,32'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-17,24.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-17,24.1'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-1,24.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-1,16.2'),
#  (0.0, 'fBodyAccJerk-bandsEnergy()-1,16.1'),
#  (0.0, 'fBodyAcc-std()-Z'),
#  (0.0, 'fBodyAcc-std()-X'),
#  (0.0, 'fBodyAcc-skewness()-Z'),
#  (0.0, 'fBodyAcc-skewness()-Y'),
#  (0.0, 'fBodyAcc-skewness()-X'),
#  (0.0, 'fBodyAcc-min()-Z'),
#  (0.0, 'fBodyAcc-min()-Y'),
#  (0.0, 'fBodyAcc-min()-X'),
#  (0.0, 'fBodyAcc-meanFreq()-Z'),
#  (0.0, 'fBodyAcc-meanFreq()-Y'),
#  (0.0, 'fBodyAcc-meanFreq()-X'),
#  (0.0, 'fBodyAcc-mean()-Z'),
#  (0.0, 'fBodyAcc-mean()-Y'),
#  (0.0, 'fBodyAcc-mean()-X'),
#  (0.0, 'fBodyAcc-maxInds-Z'),
#  (0.0, 'fBodyAcc-maxInds-Y'),
#  (0.0, 'fBodyAcc-max()-Z'),
#  (0.0, 'fBodyAcc-max()-Y'),
#  (0.0, 'fBodyAcc-max()-X'),
#  (0.0, 'fBodyAcc-mad()-Z'),
#  (0.0, 'fBodyAcc-mad()-Y'),
#  (0.0, 'fBodyAcc-kurtosis()-Z'),
#  (0.0, 'fBodyAcc-kurtosis()-Y'),
#  (0.0, 'fBodyAcc-kurtosis()-X'),
#  (0.0, 'fBodyAcc-iqr()-Z'),
#  (0.0, 'fBodyAcc-iqr()-Y'),
#  (0.0, 'fBodyAcc-iqr()-X'),
#  (0.0, 'fBodyAcc-entropy()-Z'),
#  (0.0, 'fBodyAcc-energy()-Z'),
#  (0.0, 'fBodyAcc-energy()-Y'),
#  (0.0, 'fBodyAcc-energy()-X'),
#  (0.0, 'fBodyAcc-bandsEnergy()-9,16.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-9,16.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-57,64.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-57,64.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-57,64'),
#  (0.0, 'fBodyAcc-bandsEnergy()-49,64.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-49,64.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-49,64'),
#  (0.0, 'fBodyAcc-bandsEnergy()-49,56.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-49,56'),
#  (0.0, 'fBodyAcc-bandsEnergy()-41,48.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-41,48.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-41,48'),
#  (0.0, 'fBodyAcc-bandsEnergy()-33,48.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-33,48.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-33,48'),
#  (0.0, 'fBodyAcc-bandsEnergy()-33,40.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-33,40.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-33,40'),
#  (0.0, 'fBodyAcc-bandsEnergy()-25,48.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-25,48.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-25,48'),
#  (0.0, 'fBodyAcc-bandsEnergy()-25,32.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-25,32.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-25,32'),
#  (0.0, 'fBodyAcc-bandsEnergy()-17,32.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-17,32.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-17,32'),
#  (0.0, 'fBodyAcc-bandsEnergy()-17,24.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-17,24.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-17,24'),
#  (0.0, 'fBodyAcc-bandsEnergy()-1,8.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-1,8.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-1,8'),
#  (0.0, 'fBodyAcc-bandsEnergy()-1,24.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-1,24.1'),
#  (0.0, 'fBodyAcc-bandsEnergy()-1,16.2'),
#  (0.0, 'fBodyAcc-bandsEnergy()-1,16.1'),
#  (0.0, 'angle(tBodyGyroMean,gravityMean)'),
#  (0.0, 'angle(tBodyGyroJerkMean,gravityMean)'),
#  (0.0, 'angle(tBodyAccMean,gravity)'),
#  (0.0, 'angle(tBodyAccJerkMean),gravityMean)'),
#  (0.0, 'angle(Z,gravityMean)'),
#  (0.0, 'angle(Y,gravityMean)')]

# %%
acc_features = [(importance, name) for importance, name in feature_importance if 'Acc' in name]
acc_features.sort(reverse=True)

print("Important Acc features")
for importance, name in acc_features[:5]:  # 상위 5개
    print(f'{name} : {importance}')
# Out:
# Important Acc features
# fBodyAccJerk-bandsEnergy()-1,24 : 0.06999991098061836
# tBodyAccJerkMag-sma() : 0.059819953191956016
# tBodyAccJerk-entropy()-X : 0.04989708860766342
# fBodyAccJerk-mean()-X : 0.03997422724934965
# tBodyAccJerk-sma() : 0.03997389569466526

# %%
gyro_features = [(importance, name) for importance, name in feature_importance if 'Gyro' in name]
gyro_features.sort(reverse=True)

print("Important Gyro features:")
for importance, name in gyro_features[:5]:  # 상위 5개
    print(f'{name} : {importance}')
# Out:
# Important Gyro features:
# tBodyGyroJerk-mad()-Z : 0.019999822554848046
# tBodyGyroJerk-iqr()-Z : 0.009975367109399596
# tBodyGyroJerk-sma() : 0.00994857541097856
# tBodyGyroJerkMag-sma() : 0.009931435256782436
# tBodyGyroJerk-iqr()-X : 0.009914142545957502

# %%
acc_mean_features = [(importance, name) for importance, name in acc_features if 'mean()' in name]
acc_mean_features.sort(reverse=True)

print("Important mean features:")
for importance, name in acc_mean_features[:5]:  # 상위 5개
    print(f'{name} : {importance}')
# Out:
# Important mean features:
# fBodyAccJerk-mean()-X : 0.03997422724934965
# tBodyAccJerkMag-mean() : 0.02996577084034262
# fBodyBodyAccJerkMag-mean() : 0.009940262760568258
# fBodyAccJerk-mean()-Y : 0.00990146914458558
# fBodyAccMag-mean() : 5.99154779951363e-05

# %%
gyro_mean_features = [(importance, name) for importance, name in gyro_features if 'mean()' in name]
gyro_mean_features.sort(reverse=True)

print("Important mean features:")
for importance, name in gyro_mean_features[:5]:  # 상위 5개
    print(f'{name} : {importance}')
# Out:
# Important mean features:
# tBodyGyroJerkMag-mean() : 8.59492051891117e-06
# fBodyBodyGyroMag-mean() : 6.88235600720204e-06
# tBodyGyroMag-mean() : 0.0
# tBodyGyroJerk-mean()-Z : 0.0
# tBodyGyroJerk-mean()-Y : 0.0
